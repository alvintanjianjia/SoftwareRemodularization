# %% [markdown]
# # E-SC4R: Explaining Software Clustering for Remodularisation
#
# - Tan, Alvin Jian Jia, Chun Yong Chong, and Aldeida Aleti. "E-SC4R: Explaining Software Clustering for Remodularisation." Journal of Systems and Software 186 (2022): 111162.
#
# # REARRANGE: An Effort Estimation Approach for Software Clustering-based Remodularisation

# %% [markdown]
# ## Abstract
#
# Software clustering is often used as a remodularisation technique to suggest ways to improve the internal quality of the software through some suggested refactoring operations. This project aims to provide an end-to-end pipeline to help developers in carrying out refactoring activities through the following steps:
#
# 1. Determine the most suitable clustering algorithm for a given project. (**E-SC4R**)
# 2. Estimate the effort needed to convert the current project structure to the suggested clustering result. (**REARRANGE**)

# %% [markdown]
# ## Introduction
#
# This repo contains scripts and notebooks that are used in both E-SC4R and REARRANGE. The following snippets show the general flow of the end-to-end pipeline. For more details and the full implementation, kindly refer back to the specific notebooks.

# %% [markdown]
# # E-SC4R
# <img src="README images/E-SC4R framework.PNG" width="800" height="400">
# <img src="README images/SoftwareClusteringProcess.PNG" width="800" height="400">

# %% [markdown]
# ## E-SC4R Experiment Design
# 1. Idenfitication of clustering entities
# 2. Idenfitication of clustering features
# 3. Calculation of similarity measure
# 4. Application of clustering algorithm
# 5. Evaluation of clustering Results

# %%
import json
import pandas as pd
import numpy as np
import networkx as nx
import jellyfish
import os
import shutil
import subprocess
import requests
from github import Github
from git import Repo
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering
from zipfile import ZipFile
from filecmp import dircmp
import configparser
import h2o
import scipy as sp

# %% [markdown]
# ### Identification of clustering entitites
#
# This step explores the file directory structure and extracts the clustering entities, child and parent classes.

# %%
project_name = 'Redisson'
version_name = 'redisson-3.16.0'


n_cluster = 300
affinity = 'cosine'
linkage = 'single'
rootdir = f'C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/{project_name}/{project_name}_{version_name}'
full_dir_arr = []
for root, dirs, files in os.walk(rootdir):
    #print(root)
    #print(dirs)
    for element in files:
        if '.java' in element:
            dir_string = root + '\\' + element
            full_dir_arr.append(dir_string)

cluster_dict = {}
cluster_tree = {}


for element in full_dir_arr:
    element = element.split('\\')
    child = element[-1]
    parent = element[-2]
    cluster_tree[child] = parent
    
cluster_tree
# Out:
# {'ElementsSubscribeService.java': 'redisson',
#  'JndiRedissonFactory.java': 'redisson',
#  'MapWriteBehindTask.java': 'redisson',
#  'MapWriterTask.java': 'redisson',
#  'PubSubEntry.java': 'handler',
#  'PubSubMessageListener.java': 'redisson',
#  'PubSubPatternMessageListener.java': 'redisson',
#  'PubSubPatternStatusListener.java': 'redisson',
#  'PubSubStatusListener.java': 'redisson',
#  'QueueTransferService.java': 'redisson',
#  'QueueTransferTask.java': 'redisson',
#  'RedisClusterNodes.java': 'redisson',
#  'RedisNodes.java': 'redisnode',
#  'Redisson.java': 'redisson',
#  'RedissonAtomicDouble.java': 'redisson',
#  'RedissonAtomicLong.java': 'redisson',
#  'RedissonBaseAdder.java': 'redisson',
#  'RedissonBaseLock.java': 'redisson',
#  'RedissonBatch.java': 'redisson',
#  'RedissonBinaryStream.java': 'redisson',
#  'RedissonBitSet.java': 'redisson',
#  'RedissonBlockingDeque.java': 'redisson',
#  'RedissonBlockingQueue.java': 'redisson',
#  'RedissonBloomFilter.java': 'redisson',
#  'RedissonBoundedBlockingQueue.java': 'redisson',
#  'RedissonBucket.java': 'redisson',
#  'RedissonBuckets.java': 'redisson',
#  'RedissonCountDownLatch.java': 'redisson',
#  'RedissonCountDownLatchEntry.java': 'redisson',
#  'RedissonDelayedQueue.java': 'redisson',
#  'RedissonDeque.java': 'redisson',
#  'RedissonDoubleAdder.java': 'redisson',
#  'RedissonExecutorService.java': 'redisson',
#  'RedissonExpirable.java': 'redisson',
#  'RedissonFairLock.java': 'redisson',
#  'RedissonGeo.java': 'redisson',
#  'RedissonHyperLogLog.java': 'redisson',
#  'RedissonIdGenerator.java': 'redisson',
#  'RedissonKeys.java': 'redisson',
#  'RedissonLexSortedSet.java': 'redisson',
#  'RedissonList.java': 'redisson',
#  'RedissonListMultimap.java': 'redisson',
#  'RedissonListMultimapCache.java': 'redisson',
#  'RedissonListMultimapIterator.java': 'redisson',
#  'RedissonListMultimapValues.java': 'redisson',
#  'RedissonLiveObjectService.java': 'redisson',
#  'RedissonLocalCachedMap.java': 'redisson',
#  'RedissonLock.java': 'redisson',
#  'RedissonLockEntry.java': 'redisson',
#  'RedissonLongAdder.java': 'redisson',
#  'RedissonMap.java': 'redisson',
#  'RedissonMapCache.java': 'redisson',
#  'RedissonMapEntry.java': 'redisson',
#  'RedissonMultiLock.java': 'redisson',
#  'RedissonMultimap.java': 'redisson',
#  'RedissonMultimapCache.java': 'redisson',
#  'RedissonMultiMapIterator.java': 'redisson',
#  'RedissonNode.java': 'redisson',
#  'RedissonObject.java': 'redisson',
#  'RedissonPatternTopic.java': 'redisson',
#  'RedissonPermitExpirableSemaphore.java': 'redisson',
#  'RedissonPriorityBlockingDeque.java': 'redisson',
#  'RedissonPriorityBlockingQueue.java': 'redisson',
#  'RedissonPriorityDeque.java': 'redisson',
#  'RedissonPriorityQueue.java': 'redisson',
#  'RedissonQueue.java': 'redisson',
#  'RedissonQueueSemaphore.java': 'redisson',
#  'RedissonRateLimiter.java': 'redisson',
#  'RedissonReactive.java': 'redisson',
#  'RedissonReadLock.java': 'redisson',
#  'RedissonReadWriteLock.java': 'redisson',
#  'RedissonRedLock.java': 'redisson',
#  'RedissonReference.java': 'redisson',
#  'RedissonReliableTopic.java': 'redisson',
#  'RedissonRemoteService.java': 'redisson',
#  'RedissonRingBuffer.java': 'redisson',
#  'RedissonRx.java': 'redisson',
#  'RedissonScoredSortedSet.java': 'redisson',
#  'RedissonScript.java': 'redisson',
#  'RedissonSemaphore.java': 'redisson',
#  'RedissonSet.java': 'redisson',
#  'RedissonSetCache.java': 'redisson',
#  'RedissonSetMultimap.java': 'redisson',
#  'RedissonSetMultimapCache.java': 'redisson',
#  'RedissonSetMultimapIterator.java': 'redisson',
#  'RedissonSetMultimapValues.java': 'redisson',
#  'RedissonShutdownException.java': 'redisson',
#  'RedissonSortedSet.java': 'redisson',
#  'RedissonSpinLock.java': 'redisson',
#  'RedissonStream.java': 'redisson',
#  'RedissonSubList.java': 'redisson',
#  'RedissonSubSortedSet.java': 'redisson',
#  'RedissonTimeSeries.java': 'redisson',
#  'RedissonTopic.java': 'redisson',
#  'RedissonTransferQueue.java': 'redisson',
#  'RedissonWriteLock.java': 'redisson',
#  'ScanIterator.java': 'redisson',
#  'ScanResult.java': 'redisson',
#  'SlotCallback.java': 'redisson',
#  'Version.java': 'redisson',
#  'WriteBehindService.java': 'redisson',
#  'AutoClaimResult.java': 'api',
#  'BatchOptions.java': 'api',
#  'BatchResult.java': 'api',
#  'CacheAsync.java': 'api',
#  'CacheReactive.java': 'api',
#  'CacheRx.java': 'api',
#  'ClusterNode.java': 'api',
#  'ClusterNodesGroup.java': 'api',
#  'CronSchedule.java': 'api',
#  'DefaultNameMapper.java': 'api',
#  'DefaultNatMapper.java': 'api',
#  'DeletedObjectListener.java': 'api',
#  'EvictionMode.java': 'api',
#  'ExecutorOptions.java': 'api',
#  'ExpiredObjectListener.java': 'api',
#  'FastAutoClaimResult.java': 'api',
#  'GeoEntry.java': 'api',
#  'GeoOrder.java': 'api',
#  'GeoPosition.java': 'api',
#  'GeoUnit.java': 'api',
#  'HostNatMapper.java': 'api',
#  'HostPortNatMapper.java': 'api',
#  'LocalCachedMapOptions.java': 'api',
#  'LockOptions.java': 'api',
#  'MapOptions.java': 'api',
#  'NameMapper.java': 'api',
#  'NatMapper.java': 'api',
#  'Node.java': 'api',
#  'NodeAsync.java': 'api',
#  'NodeListener.java': 'api',
#  'NodesGroup.java': 'api',
#  'NodeType.java': 'api',
#  'ObjectListener.java': 'api',
#  'PendingEntry.java': 'api',
#  'PendingResult.java': 'api',
#  'RateIntervalUnit.java': 'api',
#  'RateLimiterConfig.java': 'api',
#  'RateType.java': 'api',
#  'RAtomicDouble.java': 'api',
#  'RAtomicDoubleAsync.java': 'api',
#  'RAtomicDoubleReactive.java': 'api',
#  'RAtomicDoubleRx.java': 'api',
#  'RAtomicLong.java': 'api',
#  'RAtomicLongAsync.java': 'api',
#  'RAtomicLongReactive.java': 'api',
#  'RAtomicLongRx.java': 'api',
#  'RBatch.java': 'api',
#  'RBatchReactive.java': 'api',
#  'RBatchRx.java': 'api',
#  'RBinaryStream.java': 'api',
#  'RBinaryStreamReactive.java': 'api',
#  'RBinaryStreamRx.java': 'api',
#  'RBitSet.java': 'api',
#  'RBitSetAsync.java': 'api',
#  'RBitSetReactive.java': 'api',
#  'RBitSetRx.java': 'api',
#  'RBlockingDeque.java': 'api',
#  'RBlockingDequeAsync.java': 'api',
#  'RBlockingDequeReactive.java': 'api',
#  'RBlockingDequeRx.java': 'api',
#  'RBlockingQueue.java': 'api',
#  'RBlockingQueueAsync.java': 'api',
#  'RBlockingQueueReactive.java': 'api',
#  'RBlockingQueueRx.java': 'api',
#  'RBloomFilter.java': 'api',
#  'RBoundedBlockingQueue.java': 'api',
#  'RBoundedBlockingQueueAsync.java': 'api',
#  'RBucket.java': 'api',
#  'RBucketAsync.java': 'api',
#  'RBucketReactive.java': 'api',
#  'RBucketRx.java': 'api',
#  'RBuckets.java': 'api',
#  'RBucketsAsync.java': 'api',
#  'RBucketsReactive.java': 'api',
#  'RBucketsRx.java': 'api',
#  'RCascadeType.java': 'api',
#  'RCollectionAsync.java': 'api',
#  'RCollectionReactive.java': 'api',
#  'RCollectionRx.java': 'api',
#  'RCountDownLatch.java': 'api',
#  'RCountDownLatchAsync.java': 'api',
#  'RCountDownLatchReactive.java': 'api',
#  'RCountDownLatchRx.java': 'api',
#  'RDelayedQueue.java': 'api',
#  'RDeque.java': 'api',
#  'RDequeAsync.java': 'api',
#  'RDequeReactive.java': 'api',
#  'RDequeRx.java': 'api',
#  'RDestroyable.java': 'api',
#  'RDoubleAdder.java': 'api',
#  'RedissonClient.java': 'api',
#  'RedissonNodeInitializer.java': 'api',
#  'RedissonReactiveClient.java': 'api',
#  'RedissonRxClient.java': 'api',
#  'RemoteInvocationOptions.java': 'api',
#  'RExecutorBatchFuture.java': 'api',
#  'RExecutorFuture.java': 'api',
#  'RExecutorService.java': 'api',
#  'RExecutorServiceAsync.java': 'api',
#  'RExpirable.java': 'api',
#  'RExpirableAsync.java': 'api',
#  'RExpirableReactive.java': 'api',
#  'RExpirableRx.java': 'api',
#  'RFuture.java': 'api',
#  'RGeo.java': 'api',
#  'RGeoAsync.java': 'api',
#  'RGeoReactive.java': 'api',
#  'RGeoRx.java': 'api',
#  'RHyperLogLog.java': 'api',
#  'RHyperLogLogAsync.java': 'api',
#  'RHyperLogLogReactive.java': 'api',
#  'RHyperLogLogRx.java': 'api',
#  'RIdGenerator.java': 'api',
#  'RIdGeneratorAsync.java': 'api',
#  'RIdGeneratorReactive.java': 'api',
#  'RIdGeneratorRx.java': 'api',
#  'RKeys.java': 'api',
#  'RKeysAsync.java': 'api',
#  'RKeysReactive.java': 'api',
#  'RKeysRx.java': 'api',
#  'RLexSortedSet.java': 'api',
#  'RLexSortedSetAsync.java': 'api',
#  'RLexSortedSetReactive.java': 'api',
#  'RLexSortedSetRx.java': 'api',
#  'RList.java': 'api',
#  'RListAsync.java': 'api',
#  'RListMultimap.java': 'api',
#  'RListMultimapCache.java': 'api',
#  'RListMultimapCacheRx.java': 'api',
#  'RListMultimapReactive.java': 'api',
#  'RListMultimapRx.java': 'api',
#  'RListReactive.java': 'api',
#  'RListRx.java': 'api',
#  'RLiveObject.java': 'api',
#  'RLiveObjectService.java': 'api',
#  'RLocalCachedMap.java': 'api',
#  'RLock.java': 'api',
#  'RLockAsync.java': 'api',
#  'RLockReactive.java': 'api',
#  'RLockRx.java': 'api',
#  'RLongAdder.java': 'api',
#  'RMap.java': 'api',
#  'RMapAsync.java': 'api',
#  'RMapCache.java': 'api',
#  'RMapCacheAsync.java': 'api',
#  'RMapCacheReactive.java': 'api',
#  'RMapCacheRx.java': 'api',
#  'RMapReactive.java': 'api',
#  'RMapRx.java': 'api',
#  'RMultimap.java': 'api',
#  'RMultimapAsync.java': 'api',
#  'RMultimapCache.java': 'api',
#  'RMultimapCacheAsync.java': 'api',
#  'RMultimapCacheRx.java': 'api',
#  'RMultimapReactive.java': 'api',
#  'RMultimapRx.java': 'api',
#  'RObject.java': 'api',
#  'RObjectAsync.java': 'api',
#  'RObjectReactive.java': 'api',
#  'RObjectRx.java': 'api',
#  'RPatternTopic.java': 'api',
#  'RPatternTopicReactive.java': 'api',
#  'RPatternTopicRx.java': 'api',
#  'RPermitExpirableSemaphore.java': 'api',
#  'RPermitExpirableSemaphoreAsync.java': 'api',
#  'RPermitExpirableSemaphoreReactive.java': 'api',
#  'RPermitExpirableSemaphoreRx.java': 'api',
#  'RPriorityBlockingDeque.java': 'api',
#  'RPriorityBlockingQueue.java': 'api',
#  'RPriorityDeque.java': 'api',
#  'RPriorityQueue.java': 'api',
#  'RQueue.java': 'api',
#  'RQueueAsync.java': 'api',
#  'RQueueReactive.java': 'api',
#  'RQueueRx.java': 'api',
#  'RRateLimiter.java': 'api',
#  'RRateLimiterAsync.java': 'api',
#  'RRateLimiterReactive.java': 'api',
#  'RRateLimiterRx.java': 'api',
#  'RReadWriteLock.java': 'api',
#  'RReadWriteLockReactive.java': 'api',
#  'RReadWriteLockRx.java': 'api',
#  'RReliableTopic.java': 'api',
#  'RReliableTopicAsync.java': 'api',
#  'RReliableTopicReactive.java': 'api',
#  'RReliableTopicRx.java': 'api',
#  'RRemoteService.java': 'api',
#  'RRingBuffer.java': 'api',
#  'RRingBufferAsync.java': 'api',
#  'RRingBufferReactive.java': 'api',
#  'RRingBufferRx.java': 'api',
#  'RScheduledExecutorService.java': 'api',
#  'RScheduledExecutorServiceAsync.java': 'api',
#  'RScheduledFuture.java': 'api',
#  'RScoredSortedSet.java': 'api',
#  'RScoredSortedSetAsync.java': 'api',
#  'RScoredSortedSetReactive.java': 'api',
#  'RScoredSortedSetRx.java': 'api',
#  'RScript.java': 'api',
#  'RScriptAsync.java': 'api',
#  'RScriptReactive.java': 'api',
#  'RScriptRx.java': 'api',
#  'RSemaphore.java': 'api',
#  'RSemaphoreAsync.java': 'api',
#  'RSemaphoreReactive.java': 'api',
#  'RSemaphoreRx.java': 'api',
#  'RSet.java': 'api',
#  'RSetAsync.java': 'api',
#  'RSetCache.java': 'api',
#  'RSetCacheAsync.java': 'api',
#  'RSetCacheReactive.java': 'api',
#  'RSetCacheRx.java': 'api',
#  'RSetMultimap.java': 'api',
#  'RSetMultimapCache.java': 'api',
#  'RSetMultimapCacheRx.java': 'api',
#  'RSetMultimapReactive.java': 'api',
#  'RSetMultimapRx.java': 'api',
#  'RSetReactive.java': 'api',
#  'RSetRx.java': 'api',
#  'RSortable.java': 'api',
#  'RSortableAsync.java': 'api',
#  'RSortableReactive.java': 'api',
#  'RSortableRx.java': 'api',
#  'RSortedSet.java': 'api',
#  'RStream.java': 'api',
#  'RStreamAsync.java': 'api',
#  'RStreamReactive.java': 'api',
#  'RStreamRx.java': 'api',
#  'RTimeSeries.java': 'api',
#  'RTimeSeriesAsync.java': 'api',
#  'RTimeSeriesReactive.java': 'api',
#  'RTimeSeriesRx.java': 'api',
#  'RTopic.java': 'api',
#  'RTopicAsync.java': 'api',
#  'RTopicReactive.java': 'api',
#  'RTopicRx.java': 'api',
#  'RTransaction.java': 'api',
#  'RTransactionReactive.java': 'api',
#  'RTransactionRx.java': 'api',
#  'RTransferQueue.java': 'api',
#  'RTransferQueueAsync.java': 'api',
#  'RTransferQueueReactive.java': 'api',
#  'RTransferQueueRx.java': 'api',
#  'RType.java': 'api',
#  'SortOrder.java': 'api',
#  'StreamConsumer.java': 'api',
#  'StreamGroup.java': 'api',
#  'StreamInfo.java': 'api',
#  'StreamMessageId.java': 'api',
#  'TimeSeriesEntry.java': 'api',
#  'TransactionOptions.java': 'api',
#  'WorkerOptions.java': 'api',
#  'RCascade.java': 'annotation',
#  'REntity.java': 'annotation',
#  'RFieldAccessor.java': 'annotation',
#  'RId.java': 'annotation',
#  'RIndex.java': 'annotation',
#  'RInject.java': 'annotation',
#  'RObjectField.java': 'annotation',
#  'RRemoteAsync.java': 'annotation',
#  'RRemoteReactive.java': 'annotation',
#  'RRemoteRx.java': 'annotation',
#  'Condition.java': 'condition',
#  'Conditions.java': 'condition',
#  'TaskFailureListener.java': 'executor',
#  'TaskFinishedListener.java': 'executor',
#  'TaskListener.java': 'executor',
#  'TaskStartedListener.java': 'executor',
#  'TaskSuccessListener.java': 'executor',
#  'BaseGeoSearch.java': 'geo',
#  'BaseOptionalGeoSearch.java': 'geo',
#  'GeoSearchArgs.java': 'geo',
#  'GeoSearchNode.java': 'geo',
#  'OptionalGeoSearch.java': 'geo',
#  'ShapeGeoSearch.java': 'geo',
#  'BasePatternStatusListener.java': 'listener',
#  'BaseStatusListener.java': 'listener',
#  'ListAddListener.java': 'listener',
#  'ListInsertListener.java': 'listener',
#  'ListRemoveListener.java': 'listener',
#  'ListSetListener.java': 'listener',
#  'ListTrimListener.java': 'listener',
#  'MessageListener.java': 'listener',
#  'PatternMessageListener.java': 'listener',
#  'PatternStatusListener.java': 'listener',
#  'ScoredSortedSetAddListener.java': 'listener',
#  'SetObjectListener.java': 'listener',
#  'StatusListener.java': 'listener',
#  'MapLoader.java': 'map',
#  'MapWriter.java': 'map',
#  'EntryCreatedListener.java': 'event',
#  'EntryEvent.java': 'event',
#  'EntryExpiredListener.java': 'event',
#  'EntryRemovedListener.java': 'event',
#  'EntryUpdatedListener.java': 'event',
#  'MapEntryListener.java': 'event',
#  'RCollator.java': 'mapreduce',
#  'RCollectionMapper.java': 'mapreduce',
#  'RCollectionMapReduce.java': 'mapreduce',
#  'RCollector.java': 'mapreduce',
#  'RMapper.java': 'mapreduce',
#  'RMapReduce.java': 'mapreduce',
#  'RMapReduceExecutor.java': 'mapreduce',
#  'RReducer.java': 'mapreduce',
#  'DequeMoveArgs.java': 'queue',
#  'DequeMoveDestination.java': 'queue',
#  'DequeMoveDestinationStep.java': 'queue',
#  'DequeMoveParams.java': 'queue',
#  'DequeMoveSource.java': 'queue',
#  'BaseRedisNodes.java': 'redisnode',
#  'RedisCluster.java': 'redisnode',
#  'RedisClusterMaster.java': 'redisnode',
#  'RedisClusterMasterAsync.java': 'redisnode',
#  'RedisClusterNode.java': 'redisnode',
#  'RedisClusterNodeAsync.java': 'redisnode',
#  'RedisClusterSlave.java': 'redisnode',
#  'RedisClusterSlaveAsync.java': 'redisnode',
#  'RedisMaster.java': 'redisnode',
#  'RedisMasterAsync.java': 'redisnode',
#  'RedisMasterSlave.java': 'redisnode',
#  'RedisNode.java': 'redisnode',
#  'RedisNodeAsync.java': 'redisnode',
#  'RedisSentinel.java': 'redisnode',
#  'RedisSentinelAsync.java': 'redisnode',
#  'RedisSentinelMasterSlave.java': 'redisnode',
#  'RedisSingle.java': 'redisnode',
#  'RedisSlave.java': 'redisnode',
#  'RedisSlaveAsync.java': 'redisnode',
#  'SetSlotCommand.java': 'redisnode',
#  'BaseStreamAddArgs.java': 'stream',
#  'BaseStreamMultiReadArgs.java': 'stream',
#  'BaseStreamMultiReadGroupArgs.java': 'stream',
#  'BaseStreamReadArgs.java': 'stream',
#  'BaseStreamReadGroupArgs.java': 'stream',
#  'StreamAddArgs.java': 'stream',
#  'StreamAddArgsSource.java': 'stream',
#  'StreamAddParams.java': 'stream',
#  'StreamMultiReadArgs.java': 'stream',
#  'StreamMultiReadGroupArgs.java': 'stream',
#  'StreamReadArgs.java': 'stream',
#  'StreamReadGroupArgs.java': 'stream',
#  'StreamReadGroupParams.java': 'stream',
#  'StreamReadGroupSource.java': 'stream',
#  'StreamReadParams.java': 'stream',
#  'StreamReadSource.java': 'stream',
#  'TrimStrategy.java': 'stream',
#  'AbstractCacheMap.java': 'cache',
#  'Cache.java': 'cache',
#  'CachedValue.java': 'cache',
#  'CachedValueReference.java': 'cache',
#  'CachedValueSoftReference.java': 'cache',
#  'CachedValueWeakReference.java': 'cache',
#  'CacheKey.java': 'cache',
#  'CacheValue.java': 'cache',
#  'ExpirableValue.java': 'cache',
#  'LFUCacheMap.java': 'cache',
#  'LocalCachedMapClear.java': 'cache',
#  'LocalCachedMapDisable.java': 'cache',
#  'LocalCachedMapDisableAck.java': 'cache',
#  'LocalCachedMapDisabledKey.java': 'cache',
#  'LocalCachedMapEnable.java': 'cache',
#  'LocalCachedMapInvalidate.java': 'cache',
#  'LocalCachedMapUpdate.java': 'cache',
#  'LocalCachedMessageCodec.java': 'cache',
#  'LocalCacheListener.java': 'cache',
#  'LocalCacheView.java': 'cache',
#  'LRUCacheMap.java': 'cache',
#  'NoneCacheMap.java': 'cache',
#  'ReferenceCachedValue.java': 'cache',
#  'ReferenceCacheMap.java': 'cache',
#  'StdCachedValue.java': 'cache',
#  'BaseRedisPubSubListener.java': 'client',
#  'ChannelName.java': 'client',
#  'DefaultNettyHook.java': 'client',
#  'NettyHook.java': 'client',
#  'RedisAskException.java': 'client',
#  'RedisAuthRequiredException.java': 'client',
#  'RedisBusyException.java': 'client',
#  'RedisClient.java': 'client',
#  'RedisClientConfig.java': 'client',
#  'RedisClusterDownException.java': 'client',
#  'RedisConnection.java': 'client',
#  'RedisConnectionException.java': 'client',
#  'RedisException.java': 'client',
#  'RedisLoadingException.java': 'client',
#  'RedisMovedException.java': 'client',
#  'RedisNodeNotFoundException.java': 'client',
#  'RedisOutOfMemoryException.java': 'client',
#  'RedisPubSubConnection.java': 'client',
#  'RedisPubSubListener.java': 'client',
#  'RedisRedirectException.java': 'client',
#  'RedisResponseTimeoutException.java': 'client',
#  'RedisTimeoutException.java': 'client',
#  'RedisTryAgainException.java': 'client',
#  'SubscribeListener.java': 'client',
#  'WriteRedisConnectionException.java': 'client',
#  'BaseCodec.java': 'codec',
#  'BitSetCodec.java': 'codec',
#  'ByteArrayCodec.java': 'codec',
#  'Codec.java': 'codec',
#  'DoubleCodec.java': 'codec',
#  'IntegerCodec.java': 'codec',
#  'LongCodec.java': 'codec',
#  'StringCodec.java': 'codec',
#  'BaseConnectionHandler.java': 'handler',
#  'CommandBatchEncoder.java': 'handler',
#  'CommandDecoder.java': 'handler',
#  'CommandEncoder.java': 'handler',
#  'CommandPubSubDecoder.java': 'handler',
#  'CommandsQueue.java': 'handler',
#  'ConnectionWatchdog.java': 'handler',
#  'ErrorsLoggingHandler.java': 'handler',
#  'PingConnectionHandler.java': 'handler',
#  'PubSubKey.java': 'handler',
#  'RedisChannelInitializer.java': 'handler',
#  'RedisConnectionHandler.java': 'handler',
#  'RedisPubSubConnectionHandler.java': 'handler',
#  'State.java': 'handler',
#  'StateLevel.java': 'handler',
#  'BatchCommandData.java': 'protocol',
#  'CommandData.java': 'protocol',
#  'CommandsData.java': 'protocol',
#  'Decoder.java': 'protocol',
#  'Encoder.java': 'protocol',
#  'QueueCommand.java': 'protocol',
#  'QueueCommandHolder.java': 'protocol',
#  'RedisCommand.java': 'protocol',
#  'RedisCommands.java': 'protocol',
#  'RedisStrictCommand.java': 'protocol',
#  'ScoredEntry.java': 'protocol',
#  'Time.java': 'protocol',
#  'BitsSizeReplayConvertor.java': 'convertor',
#  'BooleanAmountReplayConvertor.java': 'convertor',
#  'BooleanNotNullReplayConvertor.java': 'convertor',
#  'BooleanNullReplayConvertor.java': 'convertor',
#  'BooleanNullSafeReplayConvertor.java': 'convertor',
#  'BooleanNumberReplayConvertor.java': 'convertor',
#  'BooleanReplayConvertor.java': 'convertor',
#  'ByteReplayConvertor.java': 'convertor',
#  'Convertor.java': 'convertor',
#  'DoubleNullSafeReplayConvertor.java': 'convertor',
#  'DoubleReplayConvertor.java': 'convertor',
#  'EmptyConvertor.java': 'convertor',
#  'EmptyMapConvertor.java': 'convertor',
#  'EmptySetConvertor.java': 'convertor',
#  'IntegerReplayConvertor.java': 'convertor',
#  'LongReplayConvertor.java': 'convertor',
#  'NumberConvertor.java': 'convertor',
#  'ShortReplayConvertor.java': 'convertor',
#  'StreamIdConvertor.java': 'convertor',
#  'StringToListConvertor.java': 'convertor',
#  'TimeObjectDecoder.java': 'convertor',
#  'TrueReplayConvertor.java': 'convertor',
#  'TypeConvertor.java': 'convertor',
#  'VoidReplayConvertor.java': 'convertor',
#  'AutoClaimDecoder.java': 'decoder',
#  'ClusterNodesDecoder.java': 'decoder',
#  'CodecDecoder.java': 'decoder',
#  'FastAutoClaimDecoder.java': 'decoder',
#  'GeoDistanceDecoder.java': 'decoder',
#  'GeoPositionDecoder.java': 'decoder',
#  'GeoPositionMapDecoder.java': 'decoder',
#  'InetSocketAddressDecoder.java': 'decoder',
#  'KeyValueMessage.java': 'decoder',
#  'ListFirstObjectDecoder.java': 'decoder',
#  'ListIteratorReplayDecoder.java': 'decoder',
#  'ListIteratorResult.java': 'decoder',
#  'ListMultiDecoder2.java': 'decoder',
#  'ListObjectDecoder.java': 'decoder',
#  'ListResultReplayDecoder.java': 'decoder',
#  'ListScanResult.java': 'decoder',
#  'ListScanResultReplayDecoder.java': 'decoder',
#  'Long2MultiDecoder.java': 'decoder',
#  'MapCacheScanResult.java': 'decoder',
#  'MapCacheScanResultReplayDecoder.java': 'decoder',
#  'MapEntriesDecoder.java': 'decoder',
#  'MapKeyDecoder.java': 'decoder',
#  'MapScanResult.java': 'decoder',
#  'MapScanResultReplayDecoder.java': 'decoder',
#  'MapValueDecoder.java': 'decoder',
#  'MultiDecoder.java': 'decoder',
#  'ObjectDecoder.java': 'decoder',
#  'ObjectFirstScoreReplayDecoder.java': 'decoder',
#  'ObjectListReplayDecoder.java': 'decoder',
#  'ObjectMapDecoder.java': 'decoder',
#  'ObjectMapEntryReplayDecoder.java': 'decoder',
#  'ObjectMapReplayDecoder.java': 'decoder',
#  'ObjectMapReplayDecoder2.java': 'decoder',
#  'ObjectSetReplayDecoder.java': 'decoder',
#  'PendingEntryDecoder.java': 'decoder',
#  'PendingResultDecoder.java': 'decoder',
#  'ScoredSortedSetPolledObjectDecoder.java': 'decoder',
#  'ScoredSortedSetRandomMapDecoder.java': 'decoder',
#  'ScoredSortedSetReplayDecoder.java': 'connection',
#  'ScoredSortedSetScanDecoder.java': 'decoder',
#  'ScoredSortedSetScanReplayDecoder.java': 'decoder',
#  'SlotsDecoder.java': 'decoder',
#  'StreamConsumerInfoDecoder.java': 'decoder',
#  'StreamGroupInfoDecoder.java': 'decoder',
#  'StreamIdDecoder.java': 'decoder',
#  'StreamInfoDecoder.java': 'decoder',
#  'StreamObjectMapReplayDecoder.java': 'decoder',
#  'StreamResultDecoder.java': 'decoder',
#  'StringDataDecoder.java': 'decoder',
#  'StringListReplayDecoder.java': 'decoder',
#  'StringMapDataDecoder.java': 'decoder',
#  'StringMapReplayDecoder.java': 'decoder',
#  'StringReplayDecoder.java': 'decoder',
#  'TimeLongObjectDecoder.java': 'decoder',
#  'TimeSeriesEntryReplayDecoder.java': 'decoder',
#  'Message.java': 'pubsub',
#  'PubSubMessage.java': 'pubsub',
#  'PubSubMessageDecoder.java': 'pubsub',
#  'PubSubPatternMessage.java': 'pubsub',
#  'PubSubPatternMessageDecoder.java': 'pubsub',
#  'PubSubStatusDecoder.java': 'pubsub',
#  'PubSubStatusMessage.java': 'pubsub',
#  'PubSubType.java': 'pubsub',
#  'ClusterConnectionManager.java': 'cluster',
#  'ClusterNodeInfo.java': 'cluster',
#  'ClusterPartition.java': 'cluster',
#  'ClusterSlotRange.java': 'cluster',
#  'AvroJacksonCodec.java': 'codec',
#  'BaseEventCodec.java': 'codec',
#  'CborJacksonCodec.java': 'codec',
#  'CompositeCodec.java': 'codec',
#  'CustomObjectInputStream.java': 'codec',
#  'DefaultReferenceCodecProvider.java': 'codec',
#  'FstCodec.java': 'codec',
#  'IonJacksonCodec.java': 'codec',
#  'JsonJacksonCodec.java': 'codec',
#  'Kryo5Codec.java': 'codec',
#  'KryoCodec.java': 'codec',
#  'LZ4Codec.java': 'codec',
#  'MapCacheEventCodec.java': 'codec',
#  'MarshallingCodec.java': 'codec',
#  'MsgPackJacksonCodec.java': 'codec',
#  'ReferenceCodecProvider.java': 'codec',
#  'SerializationCodec.java': 'codec',
#  'SmileJacksonCodec.java': 'codec',
#  'SnappyCodec.java': 'codec',
#  'SnappyCodecV2.java': 'codec',
#  'TypedJsonJacksonCodec.java': 'codec',
#  'BaseRedisBatchExecutor.java': 'command',
#  'BatchPromise.java': 'command',
#  'CommandAsyncExecutor.java': 'command',
#  'CommandAsyncService.java': 'command',
#  'CommandBatchService.java': 'command',
#  'CommandExecutor.java': 'command',
#  'CommandSyncExecutor.java': 'command',
#  'CommandSyncService.java': 'command',
#  'RedisBatchExecutor.java': 'command',
#  'RedisCommonBatchExecutor.java': 'command',
#  'RedisExecutor.java': 'command',
#  'RedisQueuedBatchExecutor.java': 'command',
#  'BaseConfig.java': 'config',
#  'BaseMasterSlaveServersConfig.java': 'config',
#  'ClusterServersConfig.java': 'config',
#  'Config.java': 'config',
#  'ConfigSupport.java': 'config',
#  'MasterSlaveServersConfig.java': 'config',
#  'PropertiesConvertor.java': 'config',
#  'ReadMode.java': 'config',
#  'RedissonNodeConfig.java': 'config',
#  'RedissonNodeFileConfig.java': 'config',
#  'ReplicatedServersConfig.java': 'config',
#  'SentinelServersConfig.java': 'config',
#  'SingleServerConfig.java': 'config',
#  'SslProvider.java': 'config',
#  'SubscriptionMode.java': 'config',
#  'TransportMode.java': 'config',
#  'AddressResolverGroupFactory.java': 'connection',
#  'ClientConnectionsEntry.java': 'connection',
#  'ConnectionEventsHub.java': 'connection',
#  'ConnectionListener.java': 'connection',
#  'ConnectionManager.java': 'connection',
#  'CRC16.java': 'connection',
#  'DnsAddressResolverGroupFactory.java': 'connection',
#  'DNSMonitor.java': 'connection',
#  'IdleConnectionWatcher.java': 'connection',
#  'MasterSlaveConnectionManager.java': 'connection',
#  'MasterSlaveEntry.java': 'connection',
#  'NodeSource.java': 'connection',
#  'RedisClientEntry.java': 'connection',
#  'ReplicatedConnectionManager.java': 'connection',
#  'RoundRobinDnsAddressResolverGroupFactory.java': 'connection',
#  'SentinelConnectionManager.java': 'connection',
#  'SingleConnectionManager.java': 'connection',
#  'SingleEntry.java': 'connection',
#  'LoadBalancer.java': 'balancer',
#  'LoadBalancerManager.java': 'balancer',
#  'RandomLoadBalancer.java': 'balancer',
#  'RoundRobinLoadBalancer.java': 'balancer',
#  'WeightedRoundRobinBalancer.java': 'balancer',
#  'BucketsDecoder.java': 'decoder',
#  'ListDrainToDecoder.java': 'decoder',
#  'MapCacheGetAllDecoder.java': 'decoder',
#  'MapGetAllDecoder.java': 'decoder',
#  'ConnectionPool.java': 'pool',
#  'MasterConnectionPool.java': 'pool',
#  'MasterPubSubConnectionPool.java': 'pool',
#  'PubSubConnectionPool.java': 'pool',
#  'SlaveConnectionPool.java': 'pool',
#  'EvictionScheduler.java': 'eviction',
#  'EvictionTask.java': 'eviction',
#  'JCacheEvictionTask.java': 'eviction',
#  'MapCacheEvictionTask.java': 'eviction',
#  'MultimapEvictionTask.java': 'eviction',
#  'ScoredSetEvictionTask.java': 'eviction',
#  'TimeSeriesEvictionTask.java': 'eviction',
#  'CronExpression.java': 'executor',
#  'RedissonClassLoader.java': 'executor',
#  'RedissonCompletionService.java': 'executor',
#  'RedissonExecutorBatchFuture.java': 'executor',
#  'RedissonExecutorFuture.java': 'executor',
#  'RedissonExecutorFutureReference.java': 'executor',
#  'RedissonExecutorRemoteService.java': 'executor',
#  'RedissonScheduledFuture.java': 'executor',
#  'RemoteExecutorService.java': 'executor',
#  'RemoteExecutorServiceAsync.java': 'executor',
#  'RemotePromise.java': 'executor',
#  'ScheduledTasksService.java': 'executor',
#  'TasksBatchService.java': 'executor',
#  'TasksRunnerService.java': 'executor',
#  'TasksService.java': 'executor',
#  'ScheduledAtFixedRateParameters.java': 'params',
#  'ScheduledCronExpressionParameters.java': 'params',
#  'ScheduledParameters.java': 'params',
#  'ScheduledWithFixedDelayParameters.java': 'params',
#  'TaskParameters.java': 'params',
#  'BaseIterator.java': 'iterator',
#  'RedissonBaseIterator.java': 'iterator',
#  'RedissonBaseMapIterator.java': 'iterator',
#  'RedissonListIterator.java': 'iterator',
#  'RedissonMapIterator.java': 'iterator',
#  'JCache.java': 'jcache',
#  'JCacheEntry.java': 'jcache',
#  'JCacheEntryEvent.java': 'jcache',
#  'JCacheEventCodec.java': 'jcache',
#  'JCacheManager.java': 'jcache',
#  'JCacheMBeanServerBuilder.java': 'jcache',
#  'JCachingProvider.java': 'jcache',
#  'JMutableEntry.java': 'jcache',
#  'EmptyStatisticsMXBean.java': 'bean',
#  'JCacheManagementMXBean.java': 'bean',
#  'JCacheStatisticsMXBean.java': 'bean',
#  'JCacheConfiguration.java': 'configuration',
#  'RedissonConfiguration.java': 'micronaut',
#  'LiveObjectSearch.java': 'liveobject',
#  'LiveObjectTemplate.java': 'liveobject',
#  'ANDCondition.java': 'condition',
#  'EQCondition.java': 'condition',
#  'GECondition.java': 'condition',
#  'GTCondition.java': 'condition',
#  'LECondition.java': 'condition',
#  'LTCondition.java': 'condition',
#  'ORCondition.java': 'condition',
#  'AccessorInterceptor.java': 'core',
#  'FieldAccessorInterceptor.java': 'core',
#  'LiveObjectInterceptor.java': 'core',
#  'RedissonObjectBuilder.java': 'core',
#  'RExpirableInterceptor.java': 'core',
#  'RMapInterceptor.java': 'core',
#  'RObjectInterceptor.java': 'core',
#  'AdvBeanCopy.java': 'misc',
#  'ClassUtils.java': 'misc',
#  'Introspectior.java': 'misc',
#  'AbstractNamingScheme.java': 'resolver',
#  'DefaultNamingScheme.java': 'resolver',
#  'LongGenerator.java': 'resolver',
#  'NamingScheme.java': 'resolver',
#  'RequiredIdResolver.java': 'resolver',
#  'RIdResolver.java': 'resolver',
#  'UUIDGenerator.java': 'resolver',
#  'BaseMapperTask.java': 'mapreduce',
#  'CollatorTask.java': 'mapreduce',
#  'CollectionMapperTask.java': 'mapreduce',
#  'Collector.java': 'mapreduce',
#  'CoordinatorTask.java': 'mapreduce',
#  'MapperTask.java': 'mapreduce',
#  'MapReduceExecutor.java': 'mapreduce',
#  'MapReduceTimeoutException.java': 'mapreduce',
#  'RedissonCollectionMapReduce.java': 'mapreduce',
#  'RedissonMapReduce.java': 'mapreduce',
#  'ReducerTask.java': 'mapreduce',
#  'SubTasksExecutor.java': 'mapreduce',
#  'AsyncCountDownLatch.java': 'misc',
#  'BiHashMap.java': 'misc',
#  'CompositeIterable.java': 'misc',
#  'CompositeIterator.java': 'misc',
#  'CountableListener.java': 'misc',
#  'Hash.java': 'misc',
#  'HashValue.java': 'transaction',
#  'HighwayHash.java': 'misc',
#  'InfinitySemaphoreLatch.java': 'misc',
#  'Injector.java': 'misc',
#  'LogHelper.java': 'misc',
#  'PromiseDelegator.java': 'misc',
#  'ProxyBuilder.java': 'misc',
#  'ReclosableLatch.java': 'misc',
#  'RedissonPromise.java': 'misc',
#  'RedisURI.java': 'misc',
#  'RPromise.java': 'misc',
#  'TransferListener.java': 'misc',
#  'AsyncSemaphore.java': 'pubsub',
#  'CountDownLatchPubSub.java': 'pubsub',
#  'LockPubSub.java': 'pubsub',
#  'PublishSubscribe.java': 'pubsub',
#  'PublishSubscribeService.java': 'pubsub',
#  'PubSubConnectionEntry.java': 'pubsub',
#  'SemaphorePubSub.java': 'pubsub',
#  'CommandReactiveBatchService.java': 'reactive',
#  'CommandReactiveExecutor.java': 'reactive',
#  'CommandReactiveService.java': 'reactive',
#  'ElementsStream.java': 'rx',
#  'IteratorConsumer.java': 'reactive',
#  'MapReactiveIterator.java': 'reactive',
#  'PublisherAdder.java': 'rx',
#  'ReactiveProxyBuilder.java': 'reactive',
#  'RedissonBatchReactive.java': 'reactive',
#  'RedissonBinaryStreamReactive.java': 'reactive',
#  'RedissonBlockingDequeReactive.java': 'reactive',
#  'RedissonBlockingQueueReactive.java': 'reactive',
#  'RedissonKeysReactive.java': 'reactive',
#  'RedissonLexSortedSetReactive.java': 'reactive',
#  'RedissonListMultimapReactive.java': 'reactive',
#  'RedissonListReactive.java': 'reactive',
#  'RedissonMapCacheReactive.java': 'reactive',
#  'RedissonMapReactive.java': 'reactive',
#  'RedissonReadWriteLockReactive.java': 'reactive',
#  'RedissonReliableTopicReactive.java': 'reactive',
#  'RedissonScoredSortedSetReactive.java': 'reactive',
#  'RedissonSetCacheReactive.java': 'reactive',
#  'RedissonSetMultimapReactive.java': 'reactive',
#  'RedissonSetReactive.java': 'reactive',
#  'RedissonTimeSeriesReactive.java': 'reactive',
#  'RedissonTopicReactive.java': 'reactive',
#  'RedissonTransactionReactive.java': 'reactive',
#  'RedissonTransferQueueReactive.java': 'reactive',
#  'SetReactiveIterator.java': 'reactive',
#  'RedissonBaseNodes.java': 'redisnode',
#  'RedissonClusterNodes.java': 'redisnode',
#  'RedissonMasterSlaveNodes.java': 'redisnode',
#  'RedissonSentinelMasterSlaveNodes.java': 'redisnode',
#  'RedissonSingleNode.java': 'redisnode',
#  'SentinelRedisNode.java': 'redisnode',
#  'AsyncRemoteProxy.java': 'remote',
#  'BaseRemoteProxy.java': 'remote',
#  'BaseRemoteService.java': 'remote',
#  'ReactiveRemoteProxy.java': 'remote',
#  'RemoteServiceAck.java': 'remote',
#  'RemoteServiceAckTimeoutException.java': 'remote',
#  'RemoteServiceCancelRequest.java': 'remote',
#  'RemoteServiceCancelResponse.java': 'remote',
#  'RemoteServiceKey.java': 'remote',
#  'RemoteServiceMethod.java': 'remote',
#  'RemoteServiceRequest.java': 'remote',
#  'RemoteServiceResponse.java': 'remote',
#  'RemoteServiceTimeoutException.java': 'remote',
#  'RequestId.java': 'remote',
#  'ResponseEntry.java': 'remote',
#  'RRemoteServiceResponse.java': 'remote',
#  'RxRemoteProxy.java': 'remote',
#  'SyncRemoteProxy.java': 'remote',
#  'CommandRxBatchService.java': 'rx',
#  'CommandRxExecutor.java': 'rx',
#  'CommandRxService.java': 'rx',
#  'RedissonBatchRx.java': 'rx',
#  'RedissonBinaryStreamRx.java': 'rx',
#  'RedissonBlockingDequeRx.java': 'rx',
#  'RedissonBlockingQueueRx.java': 'rx',
#  'RedissonKeysRx.java': 'rx',
#  'RedissonLexSortedSetRx.java': 'rx',
#  'RedissonListMultimapCacheRx.java': 'rx',
#  'RedissonListMultimapRx.java': 'rx',
#  'RedissonListRx.java': 'rx',
#  'RedissonMapCacheRx.java': 'rx',
#  'RedissonMapRx.java': 'rx',
#  'RedissonMapRxIterator.java': 'rx',
#  'RedissonReadWriteLockRx.java': 'rx',
#  'RedissonReliableTopicRx.java': 'rx',
#  'RedissonScoredSortedSetRx.java': 'rx',
#  'RedissonSetCacheRx.java': 'rx',
#  'RedissonSetMultimapCacheRx.java': 'rx',
#  'RedissonSetMultimapRx.java': 'rx',
#  'RedissonSetRx.java': 'rx',
#  'RedissonTimeSeriesRx.java': 'rx',
#  'RedissonTopicRx.java': 'rx',
#  'RedissonTransactionRx.java': 'rx',
#  'RedissonTransferQueueRx.java': 'rx',
#  'RxProxyBuilder.java': 'rx',
#  'SetRxIterator.java': 'rx',
#  'CacheConfig.java': 'cache',
#  'CacheConfigSupport.java': 'cache',
#  'NullValue.java': 'cache',
#  'RedissonCache.java': 'mybatis',
#  'RedissonCacheMeterBinderProvider.java': 'cache',
#  'RedissonCacheMetrics.java': 'cache',
#  'RedissonCacheStatisticsAutoConfiguration.java': 'cache',
#  'RedissonSpringCacheManager.java': 'cache',
#  'BeanMethodInvoker.java': 'misc',
#  'ReactiveRedissonSessionRepository.java': 'session',
#  'RedissonSessionRepository.java': 'session',
#  'EnableRedissonHttpSession.java': 'config',
#  'EnableRedissonWebSession.java': 'config',
#  'RedissonHttpSessionConfiguration.java': 'session',
#  'RedissonWebSessionConfiguration.java': 'config',
#  'AbstractRedissonNamespaceDefinitionParser.java': 'support',
#  'DelayedQueueDecorator.java': 'support',
#  'LocalCachedMapOptionsDecorator.java': 'support',
#  'ReadWriteLockDecorator.java': 'support',
#  'RedisDefinitionParser.java': 'support',
#  'RedissonDefinitionParser.java': 'support',
#  'RedissonGenericObjectDefinitionParser.java': 'support',
#  'RedissonLiveObjectDefinitionParser.java': 'support',
#  'RedissonLiveObjectRegistrationDefinitionParser.java': 'support',
#  'RedissonMultiLockDefinitionParser.java': 'support',
#  'RedissonNamespaceDecorator.java': 'support',
#  'RedissonNamespaceDefaultDecorator.java': 'support',
#  'RedissonNamespaceHandlerSupport.java': 'support',
#  'RedissonNamespaceParserSupport.java': 'support',
#  'RedissonNestedElementAwareDecorator.java': 'support',
#  'RedissonReadAndWriteLockDefinitionParser.java': 'support',
#  'RedissonRPCClientDefinitionParser.java': 'support',
#  'RedissonRPCServerDefinitionParser.java': 'support',
#  'RemoteInvocationOptionDecorator.java': 'support',
#  'ReactiveRedissonResourceHolder.java': 'transaction',
#  'ReactiveRedissonTransactionManager.java': 'transaction',
#  'ReactiveRedissonTransactionObject.java': 'transaction',
#  'RedissonTransactionHolder.java': 'transaction',
#  'RedissonTransactionManager.java': 'transaction',
#  'RedissonTransactionObject.java': 'transaction',
#  'BaseTransactionalMap.java': 'transaction',
#  'BaseTransactionalMapCache.java': 'transaction',
#  'BaseTransactionalObject.java': 'transaction',
#  'BaseTransactionalSet.java': 'transaction',
#  'HashKey.java': 'transaction',
#  'RedissonTransaction.java': 'transaction',
#  'RedissonTransactionalBucket.java': 'transaction',
#  'RedissonTransactionalBuckets.java': 'transaction',
#  'RedissonTransactionalLocalCachedMap.java': 'transaction',
#  'RedissonTransactionalLock.java': 'transaction',
#  'RedissonTransactionalMap.java': 'transaction',
#  'RedissonTransactionalMapCache.java': 'transaction',
#  'RedissonTransactionalSet.java': 'transaction',
#  'RedissonTransactionalSetCache.java': 'transaction',
#  'TransactionalSet.java': 'transaction',
#  'TransactionalSetCache.java': 'transaction',
#  'TransactionException.java': 'transaction',
#  'TransactionTimeoutException.java': 'transaction',
#  'DeleteOperation.java': 'operation',
#  'TouchOperation.java': 'operation',
#  'TransactionalOperation.java': 'operation',
#  'UnlinkOperation.java': 'operation',
#  'BucketCompareAndSetOperation.java': 'bucket',
#  'BucketGetAndDeleteOperation.java': 'bucket',
#  'BucketGetAndSetOperation.java': 'bucket',
#  'BucketSetOperation.java': 'bucket',
#  'BucketsTrySetOperation.java': 'bucket',
#  'BucketTrySetOperation.java': 'bucket',
#  'MapAddAndGetOperation.java': 'map',
#  'MapCacheFastPutIfAbsentOperation.java': 'map',
#  'MapCacheFastPutOperation.java': 'map',
#  'MapCachePutIfAbsentOperation.java': 'map',
#  'MapCachePutOperation.java': 'map',
#  'MapFastPutIfAbsentOperation.java': 'map',
#  'MapFastPutIfExistsOperation.java': 'map',
#  'MapFastPutOperation.java': 'map',
#  'MapFastRemoveOperation.java': 'map',
#  'MapOperation.java': 'map',
#  'MapPutIfAbsentOperation.java': 'map',
#  'MapPutIfExistsOperation.java': 'map',
#  'MapPutOperation.java': 'map',
#  'MapRemoveOperation.java': 'map',
#  'MapReplaceOperation.java': 'map',
#  'AddCacheOperation.java': 'set',
#  'AddOperation.java': 'set',
#  'MoveOperation.java': 'set',
#  'RemoveCacheOperation.java': 'set',
#  'RemoveOperation.java': 'set',
#  'SetOperation.java': 'set',
#  'BaseConcurrentTest.java': 'redisson',
#  'BaseMapTest.java': 'redisson',
#  'BaseReactiveTest.java': 'redisson',
#  'BaseTest.java': 'redisson',
#  'ClusterRunner.java': 'redisson',
#  'CommandHandlersTest.java': 'redisson',
#  'ConcurrentRedissonSortedSetTest.java': 'redisson',
#  'ErrorsCodec.java': 'redisson',
#  'LockOptionsTest.java': 'redisson',
#  'RedisClientTest.java': 'redisson',
#  'RedisRunner.java': 'redisson',
#  'RedissonAtomicDoubleTest.java': 'redisson',
#  'RedissonAtomicLongReactiveTest.java': 'redisson',
#  'RedissonAtomicLongTest.java': 'redisson',
#  'RedissonBaseMultimapCacheTest.java': 'redisson',
#  'RedissonBatchTest.java': 'redisson',
#  'RedissonBinaryStreamReactiveTest.java': 'redisson',
#  'RedissonBinaryStreamTest.java': 'redisson',
#  ...}

# %%
cluster_tree
