# %%
import pandas as pd

# %%
df.loc[(df['project_name']==project_name)].head()
# Out:
#                 project_name   project_version  cluster_division   affinity  \
# 18975  immutables-immutables  immutables-2.7.5                 5  euclidean
# 18976  immutables-immutables  immutables-2.7.5                 5  euclidean
# 18977  immutables-immutables  immutables-2.7.5                 5  euclidean
# 18978  immutables-immutables  immutables-2.7.5                 5         l1
# 18979  immutables-immutables  immutables-2.7.5                 5         l1
#
#         linkage  MoJo_results
# 18975  complete           387
# 18976   average           472
# 18977    single           410
# 18978  complete           377
# 18979   average           234

# %%
df = pd.read_csv('JSS_paper_baseline_agglo.csv')

# %%
df.head()
# Out:
#            project_name project_version  cluster_division   affinity  \
# 0  bkromhout-realm-java         v0.89.0                 5  euclidean
# 1  bkromhout-realm-java         v0.89.0                 5  euclidean
# 2  bkromhout-realm-java         v0.89.0                 5  euclidean
# 3  bkromhout-realm-java         v0.89.0                 5         l1
# 4  bkromhout-realm-java         v0.89.0                 5         l1
#
#     linkage  MoJo_results
# 0  complete            91
# 1   average           147
# 2    single            87
# 3  complete            76
# 4   average            66

# %%
project_name = 'web3j-web3j'
version = 'v4.6.1'

affinity = 'cosine'
linkage = 'complete'
cluster_division = 10

# %%
test = df.loc[(df['project_name']==project_name) \
       & (df['cluster_division']==cluster_division) \
       & (df['affinity']==affinity) \
       & (df['linkage']==linkage) \
       & (df['project_version']==version)]

test.head(30)
# Out:
#       project_name project_version  cluster_division affinity   linkage  \
# 56322  web3j-web3j          v4.6.1                10   cosine  complete
#
#        MoJo_results
# 56322           378

# %%
affinity = 'manhattan'
linkage = 'single'
cluster_division = 10

test = df.loc[(df['project_name']==project_name) \
       & (df['cluster_division']==cluster_division) \
       & (df['affinity']==affinity) \
       & (df['linkage']==linkage) \
       & (df['project_version']==version)]

test.head(30)
# Out:
#       project_name project_version  cluster_division   affinity linkage  \
# 56321  web3j-web3j          v4.6.1                10  manhattan  single
#
#        MoJo_results
# 56321            90

# %%
#project_name = 'coobird-thumbnailator'
#version = '0.4.9'
affinity = 'manhattan'
linkage = 'average'
cluster_division = 25

#affinity = 'cosine'
#linkage = 'average'
#cluster_division = 15

# %%
test = df.loc[(df['project_name']==project_name) \
       & (df['cluster_division']==cluster_division) \
       & (df['affinity']==affinity) \
       & (df['linkage']==linkage) \
       & (df['project_version']==version)]

test.head(30)
# Out:
#                        project_name    project_version  cluster_division  \
# 7720  facebook-facebook-android-sdk  sdk-version-5.9.0                25
#
#        affinity  linkage  MoJo_results
# 7720  manhattan  average            50
