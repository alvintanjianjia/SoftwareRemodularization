# %%
import json
import pandas as pd
import numpy as np
import networkx as nx
import os
import shutil
import subprocess
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering

# %%
len_data_arr = []
results_data_arr_agglo = []
results_data_arr_bunch = []

agglo_bool = False
bunch_bool = False
for root, dirs, files in os.walk('bunch_old'):
    for file in files:
        print(file)
        #print(file.split('_')[-1])
        if file.split('_')[-1] == 'len.txt':
            #print(file, 'len')
            proj_len_file = open('bunch_old/' + file)
            proj_name = file.split('_')[0]
            proj_len = proj_len_file.readline().replace('\n','')
            len_data_arr.append([proj_name, proj_len])
            proj_len_file.close()
        elif file.split('_')[-1] == 'results.txt':
            #print(file, 'results')
            proj_result_file = open('bunch_old/' + file)
            proj_name = file.split('_')[0]
            
            initial_line = 2 - 1
            initial_line_result = 5 - 1
            tmp_arr = []
            
            for i, line in enumerate(proj_result_file):
                
                if i == initial_line:
                    line = line.replace('MoJo', '')
                    line = line.replace('.rsf', '')
                    line = line.replace('(', '')
                    line = line.replace(')', '')
                    line = line.split('_')
                    name = line[1].split('/')[-1]
                    #version = line[0].split('-')[-1]
                    version = line[2]
                    print(line)
                    ## If gathers results for bunch
                    if line[3] == 'exhaustive' or line[3] == 'hillclimbing' or line[3] == 'ga':
                        bunch_bool = True
                        method = line[3]
                        tmp_arr.append(name)
                        tmp_arr.append(version)
                        tmp_arr.append(method)
                        
                        initial_line += 5
                        
                    
                    
                    ## Else gathers results for agglomerative
                    else:
                        agglo_bool = True
                        n_cluster = line[3]
                        affinity = line[4]
                        linkage = line[5]
                        #print(line)
                        #print('Version', version)
                        initial_line += 5
                        tmp_arr.append(name)
                        tmp_arr.append(version)
                        tmp_arr.append(n_cluster)
                        tmp_arr.append(affinity)
                        tmp_arr.append(linkage)
                        
                elif i == initial_line_result:
                    n_MoJo = line.split(' ')[-1].split('\n')[0]

                    #print(line)
                    initial_line_result += 5
                    tmp_arr.append(n_MoJo)
                    #tmp_arr.append((1 - (float(n_MoJo) / float(num_class))) * 100)
                    
                    if agglo_bool == True:
                        results_data_arr_agglo.append(tmp_arr)
                        agglo_bool = False
                    elif bunch_bool == True:
                        results_data_arr_bunch.append(tmp_arr)
                        bunch_bool = False
                    tmp_arr = []
# Out:
# web3j-web3j_max_len.txt
# web3j-web3j_results.txt
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'complete', 'b = 380\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'average', 'b = 449\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'euclidean', 'single', 'b = 151\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'complete', 'b = 287\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'average', 'b = 161\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l1', 'single', 'b = 142\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'complete', 'b = 380\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'average', 'b = 449\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'l2', 'single', 'b = 151\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'complete', 'b = 287\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'average', 'b = 161\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'manhattan', 'single', 'b = 142\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'complete', 'b = 444\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'average', 'b = 429\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '5', 'cosine', 'single', 'b = 159\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'complete', 'b = 338\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'average', 'b = 434\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'euclidean', 'single', 'b = 120\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'complete', 'b = 231\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'average', 'b = 134\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l1', 'single', 'b = 112\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'complete', 'b = 338\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'average', 'b = 434\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'l2', 'single', 'b = 120\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'complete', 'b = 231\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'average', 'b = 134\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'manhattan', 'single', 'b = 112\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'complete', 'b = 440\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'average', 'b = 422\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '7', 'cosine', 'single', 'b = 127\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'complete', 'b = 212\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'average', 'b = 280\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'euclidean', 'single', 'b = 98\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'complete', 'b = 212\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'average', 'b = 102\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l1', 'single', 'b = 90\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'complete', 'b = 212\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'average', 'b = 280\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'l2', 'single', 'b = 98\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'complete', 'b = 212\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'average', 'b = 102\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'manhattan', 'single', 'b = 90\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'complete', 'b = 414\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'average', 'b = 409\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '10', 'cosine', 'single', 'b = 106\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'complete', 'b = 140\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'average', 'b = 170\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'euclidean', 'single', 'b = 81\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'complete', 'b = 184\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'average', 'b = 82\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l1', 'single', 'b = 74\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'complete', 'b = 140\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'average', 'b = 170\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'l2', 'single', 'b = 81\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'complete', 'b = 184\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'average', 'b = 82\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'manhattan', 'single', 'b = 74\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'complete', 'b = 348\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'average', 'b = 369\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '15', 'cosine', 'single', 'b = 69\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '20', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '20', 'euclidean', 'complete', 'b = 115\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1',
n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'complete', 'b = 321\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'average', 'b = 424\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'l2', 'single', 'b = 111\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'complete', 'b = 216\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'average', 'b = 125\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'manhattan', 'single', 'b = 108\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'complete', 'b = 430\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'average', 'b = 418\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '7', 'cosine', 'single', 'b = 135\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'complete', 'b = 199\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'average', 'b = 258\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'euclidean', 'single', 'b = 90\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'complete', 'b = 195\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'average', 'b = 104\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l1', 'single', 'b = 89\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'complete', 'b = 199\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'average', 'b = 258\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'l2', 'single', 'b = 90\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'complete', 'b = 195\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'average', 'b = 104\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'manhattan', 'single', 'b = 89\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'complete', 'b = 384\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'average', 'b = 397\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '10', 'cosine', 'single', 'b = 112\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'complete', 'b = 140\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'average', 'b = 171\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'euclidean', 'single', 'b = 78\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'complete', 'b = 173\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'average', 'b = 83\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l1', 'single', 'b = 76\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'complete', 'b = 140\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'average', 'b = 171\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'l2', 'single', 'b = 78\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'complete', 'b = 173\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'average', 'b = 83\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'manhattan', 'single', 'b = 76\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'complete', 'b = 316\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'average', 'b = 367\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '15', 'cosine', 'single', 'b = 72\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'complete', 'b = 109\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'average', 'b = 127\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'euclidean', 'single', 'b = 72\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'complete', 'b = 95\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'average', 'b = 70\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l1', 'single', 'b = 63\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'complete', 'b = 109\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'average', 'b = 127\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'l2', 'single', 'b = 72\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'complete', 'b = 95\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'average', 'b = 70\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'manhattan', 'single', 'b = 63\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'complete', 'b = 239\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'average', 'b = 297\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '20', 'cosine', 'single', 'b = 65\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'complete', 'b = 103\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'average', 'b = 109\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'euclidean', 'single', 'b = 67\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'complete', 'b = 93\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'average', 'b = 61\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l1', 'single', 'b = 59\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'complete', 'b = 103\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'average', 'b = 109\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'l2', 'single', 'b = 67\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'complete', 'b = 93\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'average', 'b = 61\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'manhattan', 'single', 'b = 59\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'complete', 'b = 195\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'average', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'average', 'b = 268\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'single', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '25', 'cosine', 'single', 'b = 60\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', '5', 'euclidean', 'complete', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', '5', 'euclidean', 'complete', 'b = 380\n']
# ...
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'b = 339\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'b = 341\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'b = 309\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'b = 321\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'b = 359\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'b = 399\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'b = 323\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'b = 371\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'b = 343\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'hillclimbing', 'b = 428\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'ga', 'b = 436\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'exhaustive', 'b = 427\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'hillclimbing', 'b = 439\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'ga', 'b = 391\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'exhaustive', 'b = 446\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'hillclimbing', 'b = 424\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'ga', 'b = 358\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'exhaustive', 'b = 400\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'hillclimbing', 'b = 306\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'ga', 'b = 267\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'exhaustive', 'b = 356\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'hillclimbing', 'b = 335\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'ga', 'b = 397\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'exhaustive', 'b = 369\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'hillclimbing', 'b = 321\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'ga', 'b = 328\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'exhaustive', 'b = 378\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'b = 398\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'b = 347\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'b = 333\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'b = 370\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'b = 401\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'b = 296\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'b = 380\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'b = 382\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'b = 403\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'hillclimbing', 'b = 362\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'ga', 'b = 435\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'exhaustive', 'b = 372\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'hillclimbing', 'b = 374\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'ga', 'b = 363\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', 'exhaustive', 'b = 360\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'hillclimbing', 'b = 247\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'ga', 'b = 329\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', 'exhaustive', 'b = 356\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'hillclimbing', 'b = 383\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'ga', 'b = 413\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0', 'exhaustive', 'b = 433\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'hillclimbing', 'b = 310\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'ga', 'b = 384\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.9', 'exhaustive', 'b = 379\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'hillclimbing', 'b = 353\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'ga', 'b = 359\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.8', 'exhaustive', 'b = 361\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'hillclimbing', 'b = 267\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'ga', 'b = 334\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.7', 'exhaustive', 'b = 364\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'hillclimbing', 'b = 368\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'ga', 'b = 375\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.6', 'exhaustive', 'b = 295\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'hillclimbing', 'b = 366\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'ga', 'b = 386\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.5', 'exhaustive', 'b = 357\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'hillclimbing', 'b = 370\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'ga', 'b = 378\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', 'exhaustive', 'b = 375\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'hillclimbing', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'hillclimbing', 'b = 379\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'ga', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'ga', 'b = 409\n']
# ['C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'exhaustive', 'a,C:/Users/user/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', 'exhaustive', 'b = 418\n']

# %%
old_bunch = pd.DataFrame(results_data_arr_bunch)

# %%
len_data_arr = []
results_data_arr_agglo = []
results_data_arr_bunch = []

agglo_bool = False
bunch_bool = False
for root, dirs, files in os.walk('bunch_new'):
    for file in files:
        print(file)
        #print(file.split('_')[-1])
        if file.split('_')[-1] == 'len.txt':
            #print(file, 'len')
            proj_len_file = open('bunch_new/' + file)
            proj_name = file.split('_')[0]
            proj_len = proj_len_file.readline().replace('\n','')
            len_data_arr.append([proj_name, proj_len])
            proj_len_file.close()
        elif file.split('_')[-1] == 'results.txt':
            #print(file, 'results')
            proj_result_file = open('bunch_new/' + file)
            proj_name = file.split('_')[0]
            
            initial_line = 2 - 1
            initial_line_result = 5 - 1
            tmp_arr = []
            
            for i, line in enumerate(proj_result_file):
                
                if i == initial_line:
                    line = line.replace('MoJo', '')
                    line = line.replace('.rsf', '')
                    line = line.replace('(', '')
                    line = line.replace(')', '')
                    line = line.split('_')
                    name = line[1].split('/')[-1]
                    #version = line[0].split('-')[-1]
                    version = line[2]
                    print(line)
                    ## If gathers results for bunch
                    if line[4] == 'exhaustive' or line[4] == 'hillclimbing' or line[4] == 'ga':
                        bunch_bool = True
                        method = line[3]
                        tmp_arr.append(name)
                        tmp_arr.append(version)
                        tmp_arr.append(method)
                        
                        initial_line += 5
                        
                    
                    
                    ## Else gathers results for agglomerative
                    else:
                        agglo_bool = True
                        n_cluster = line[3]
                        affinity = line[4]
                        linkage = line[5]
                        #print(line)
                        #print('Version', version)
                        initial_line += 5
                        tmp_arr.append(name)
                        tmp_arr.append(version)
                        tmp_arr.append(n_cluster)
                        tmp_arr.append(affinity)
                        tmp_arr.append(linkage)
                        
                elif i == initial_line_result:
                    n_MoJo = line.split(' ')[-1].split('\n')[0]

                    #print(line)
                    initial_line_result += 5
                    tmp_arr.append(n_MoJo)
                    #tmp_arr.append((1 - (float(n_MoJo) / float(num_class))) * 100)
                    
                    if agglo_bool == True:
                        results_data_arr_agglo.append(tmp_arr)
                        agglo_bool = False
                    elif bunch_bool == True:
                        results_data_arr_bunch.append(tmp_arr)
                        bunch_bool = False
                    tmp_arr = []
# Out:
# web3j-web3j-newbunch_max_len.txt
# web3j-web3j-newbunch_results.txt
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqincrw', 'b = 401\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'basicmq', 'b = 391\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqincr', 'b = 455\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomq', 'b = 404\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'hillclimbing', 'turbomqw', 'b = 383\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqincrw', 'b = 406\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'basicmq', 'b = 424\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqincr', 'b = 379\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomq', 'b = 415\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'exhaustive', 'turbomqw', 'b = 393\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqincrw', 'b = 408\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'basicmq', 'b = 428\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqincr', 'b = 365\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomq', 'b = 386\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.1', '', 'ga', 'turbomqw', 'b = 433\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqincrw', 'b = 381\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'basicmq', 'b = 400\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqincr', 'b = 270\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomq', 'b = 408\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'hillclimbing', 'turbomqw', 'b = 370\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomqincrw', 'b = 345\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'basicmq', 'b = 496\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomqincr', 'b = 457\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomq', 'b = 420\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android', '', 'exhaustive', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.6.0-android',
n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'exhaustive', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'exhaustive', 'turbomq', 'b = 363\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'exhaustive', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'exhaustive', 'turbomqw', 'b = 346\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqincrw', 'b = 323\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'basicmq', 'b = 423\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqincr', 'b = 223\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomq', 'b = 392\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.4', '', 'ga', 'turbomqw', 'b = 422\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqincrw', 'b = 384\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'basicmq', 'b = 334\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqincr', 'b = 354\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomq', 'b = 386\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'hillclimbing', 'turbomqw', 'b = 371\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqincrw', 'b = 387\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'basicmq', 'b = 343\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqincr', 'b = 391\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomq', 'b = 345\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'exhaustive', 'turbomqw', 'b = 396\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqincrw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqincrw', 'b = 376\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'basicmq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'basicmq', 'b = 411\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqincr', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqincr', 'b = 362\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomq', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomq', 'b = 325\n']
# ['C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqw', 'a,C:/Users/tanji/Desktop/SoftwareRemodularization/', '1.2.1/web3j-web3j/web3j-web3j', 'v4.5.2', '', 'ga', 'turbomqw', 'b = 370\n']

# %%
new_bunch = pd.DataFrame(results_data_arr_bunch)

# %%
old_bunch.head()
# Out:
#              0               1             2    3
# 0  web3j-web3j          v4.6.1  hillclimbing  362
# 1  web3j-web3j          v4.6.1  hillclimbing  388
# 2  web3j-web3j          v4.6.1            ga  333
# 3  web3j-web3j          v4.6.1    exhaustive  438
# 4  web3j-web3j  v4.6.0-android  hillclimbing  384

# %%
new_bunch.head()
# Out:
#              0       1 2    3
# 0  web3j-web3j  v4.6.1    394
# 1  web3j-web3j  v4.6.1    390
# 2  web3j-web3j  v4.6.1    412
# 3  web3j-web3j  v4.6.1    404
# 4  web3j-web3j  v4.6.1    383

# %%
old_bunch.columns = ['name', 'version', 'method', 'mojo']
new_bunch.columns = ['name', 'version', 'method', 'mojo']

# %%
old_bunch['mojo'].min()
# Out:
# '247'

# %%
new_bunch['mojo'].min()
# Out:
# '223'

# %%
1 - (247/643)
# Out:
# 0.6158631415241058

# %%
1 - (223/643)
# Out:
# 0.6531881804043547

# %%
=
