# %%
import pandas as pd
import os
import shutil

from github import Github

# %%
project_releases = pd.read_csv('complete_links_allVersions_limit20.csv')

# %%
project_releases.head(5)
# Out:
#   project_name                    project_link    version_name  \
# 0  web3j-web3j  https://github.com/web3j/web3j          v4.6.1
# 1  web3j-web3j  https://github.com/web3j/web3j  v4.6.0-android
# 2  web3j-web3j  https://github.com/web3j/web3j          v4.6.0
# 3  web3j-web3j  https://github.com/web3j/web3j          v4.5.9
# 4  web3j-web3j  https://github.com/web3j/web3j          v4.5.8
#
#                                               commit  major_version_x  \
# 0  Commit(sha="8e94d2bcf305358d030bab9f89d4692bb3...                4
# 1  Commit(sha="9ff030a628caf2c3a77e8952bbf7feb890...                4
# 2  Commit(sha="5877c308e11c0de8e24e50c882effa8435...                4
# 3  Commit(sha="6c23f373ce8c30a38331c4eebf46517be5...                4
# 4  Commit(sha="62df9d1c91281664c8534b994a4bbf0941...                4
#
#    major_version_int  major_version_y  count  rank
# 0                4.0                4     30   1.0
# 1                4.0                4     30   1.0
# 2                4.0                4     30   1.0
# 3                4.0                4     30   1.0
# 4                4.0                4     30   1.0

# %%
finished_project_arr = []
finished_project = open('finished_ck_projects.txt', 'r')
for line in finished_project:
    finished_project_arr.append(line.split('\n')[0])
finished_project.close()


#finished_project_arr = ['web3j-web3j', 'voxeolabs-moho']
#finished_project_arr = ['voxeolabs-moho']


for project_name in project_releases['project_name'].unique():
    max_value_rsf = 0
    if project_name not in finished_project_arr:
        current_project = pd.DataFrame(project_releases[project_releases['project_name'] == project_name])
        current_project['rank'] = current_project['version_name'].rank()
        current_project = current_project.sort_values(by=['rank'], ascending=False)

        
        ### Download dataset
        try:
            os.mkdir('raw_sourcecode/' + project_name)
        except:
            pass
        for row in current_project.iterrows():
            print('Processing: ' + project_name + '/' + project_name + '_' + row[1]['version_name'])
            command = 'sudo git config user.email "tanjianjia@gmail.com" & sudo git clone ' + row[1]['project_link'] +  ' raw_sourcecode/' + project_name + '/' + project_name + '_' + row[1]['version_name']
            #print(command)
            #print(os.system(command))
            os.system(command)
            
            commit = row[1]['commit'].replace('Commit(sha="','')
            commit = commit.replace('")','')
            
            command = 'cd raw_sourcecode/' + project_name + '/' + project_name +'_' + row[1]['version_name']+'/' + ' \nsudo git checkout ' + commit
            #print(command)
            #print(os.system(command))
            os.system(command)
            
            
            print('Currently processing: ' + project_name)
            command = 'java -jar ck-0.3.3-SNAPSHOT-jar-with-dependencies.jar raw_sourcecode/' + project_name + '/' + project_name + '_' + row[1]['version_name']
            os.system(command)
            os.rename('class.csv', project_name + '_' + row[1]['version_name'] + '_class.csv')
            os.rename('field.csv',  project_name + '_' + row[1]['version_name'] + '_field.csv')
            os.rename('method.csv', project_name + '_' + row[1]['version_name'] + '_method.csv')
            
            shutil.move(project_name + '_' + row[1]['version_name'] + '_class.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_class.csv')
            shutil.move(project_name + '_' + row[1]['version_name'] + '_field.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_field.csv')
            shutil.move(project_name + '_' + row[1]['version_name'] + '_method.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_method.csv')

            command = 'sudo rm raw_sourcecode/' + project_name + '/' + project_name +'_' + row[1]['version_name']+ ' -r'
            #print(command)
            #print(os.system(command))
            os.system(command)
            
            print('Finish processing: ' + project_name + '/' + project_name + '_' + row[1]['version_name'])
        
        finished_project = open('finished_ck_projects.txt', 'a')
        finished_project.write(project_name + '\n')
        finished_project.close()
# Out:
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.9
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.9
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.8
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.8
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.7
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.7
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.6
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.6
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.5
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.5
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.4
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.4
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.3
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.3
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.2
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.2
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.15
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.15
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.14
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.14
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.13
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.13
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.12
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.12
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.11
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.11
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.10
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.10
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.1
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.1
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.0
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.9.0
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.9
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.9
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.8
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.8
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.7
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.7
# Processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.6
# Currently processing: pxb1988-dex2jar
# Finish processing: pxb1988-dex2jar/pxb1988-dex2jar_0.0.7.6
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.4.0
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.4.0
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.2
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.2
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.1
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.1
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.0
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.3.0
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.2.1
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.2.1
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.2.0
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.2.0
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.3
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.3
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.2
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.2
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.1
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.1
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.0
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.1.0
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.9
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.9
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.8
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.8
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.7
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.7
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.6
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.6
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.5
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.5
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.4
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.4
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.3
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.3
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.2
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.2
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.1
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.1
# Processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.0
# Currently processing: permissions-dispatcher-PermissionsDispatcher
# Finish processing: permissions-dispatcher-PermissionsDispatcher/permissions-dispatcher-PermissionsDispatcher_2.0.0
# Processing: javaparser-javaparser/javaparser-javaparser_v3.13.10
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_v3.13.10
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.9.1
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.9.1
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.9.0
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.9.0
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.3
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.3
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.2
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.2
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.1
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.1
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.0
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.8.0
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.7.1
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.7.1
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.7.0
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.7.0
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.9
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.9
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.8
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.8
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.7
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.7
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.6
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.6
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.5
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.5
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.4
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.4
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.3
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.3
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.27
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.27
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.26
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.26
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.25
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.25
# Processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.24
# Currently processing: javaparser-javaparser
# Finish processing: javaparser-javaparser/javaparser-javaparser_javaparser-parent-3.6.24
# Processing: javafunk-funk/javafunk-funk_funk-0.2.0
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.2.0
# Processing: javafunk-funk/javafunk-funk_funk-0.1.9
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.9
# Processing: javafunk-funk/javafunk-funk_funk-0.1.8
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.8
# Processing: javafunk-funk/javafunk-funk_funk-0.1.7
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.7
# Processing: javafunk-funk/javafunk-funk_funk-0.1.6
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.6
# Processing: javafunk-funk/javafunk-funk_funk-0.1.5
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.5
# Processing: javafunk-funk/javafunk-funk_funk-0.1.4
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.4
# Processing: javafunk-funk/javafunk-funk_funk-0.1.3
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.3
# Processing: javafunk-funk/javafunk-funk_funk-0.1.25
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.25
# Processing: javafunk-funk/javafunk-funk_funk-0.1.24
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.24
# Processing: javafunk-funk/javafunk-funk_funk-0.1.23
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.23
# Processing: javafunk-funk/javafunk-funk_funk-0.1.22
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.22
# Processing: javafunk-funk/javafunk-funk_funk-0.1.21
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.21
# Processing: javafunk-funk/javafunk-funk_funk-0.1.20
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.20
# Processing: javafunk-funk/javafunk-funk_funk-0.1.2
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.2
# Processing: javafunk-funk/javafunk-funk_funk-0.1.18
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.18
# Processing: javafunk-funk/javafunk-funk_funk-0.1.17
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.17
# Processing: javafunk-funk/javafunk-funk_funk-0.1.16
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.16
# Processing: javafunk-funk/javafunk-funk_funk-0.1.15
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.15
# Processing: javafunk-funk/javafunk-funk_funk-0.1.14
# Currently processing: javafunk-funk
# Finish processing: javafunk-funk/javafunk-funk_funk-0.1.14
# Processing: java-native-accessjna/java-native-accessjna_v3.2.1
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.2.1
# Processing: java-native-accessjna/java-native-accessjna_v3.2
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.2
# Processing: java-native-accessjna/java-native-accessjna_v3.1
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.1
# Processing: java-native-accessjna/java-native-accessjna_v3.0.9
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.0.9
# Processing: java-native-accessjna/java-native-accessjna_v3.0.13
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.0.13
# Processing: java-native-accessjna/java-native-accessjna_v3.0.12
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.0.12
# Processing: java-native-accessjna/java-native-accessjna_v3.0.11
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.0.11
# Processing: java-native-accessjna/java-native-accessjna_v3.0.10
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_v3.0.10
# Processing: java-native-accessjna/java-native-accessjna_3.5.2
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.5.2
# Processing: java-native-accessjna/java-native-accessjna_3.5.1
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.5.1
# Processing: java-native-accessjna/java-native-accessjna_3.5.0
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.5.0
# Processing: java-native-accessjna/java-native-accessjna_3.4.2
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.4.2
# Processing: java-native-accessjna/java-native-accessjna_3.4.1
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.4.1
# Processing: java-native-accessjna/java-native-accessjna_3.4.0-maven
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.4.0-maven
# Processing: java-native-accessjna/java-native-accessjna_3.4.0
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.4.0
# Processing: java-native-accessjna/java-native-accessjna_3.3.0
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.3.0
# Processing: java-native-accessjna/java-native-accessjna_3.2.7
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.2.7
# Processing: java-native-accessjna/java-native-accessjna_3.2.5
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.2.5
# Processing: java-native-accessjna/java-native-accessjna_3.2.4
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.2.4
# Processing: java-native-accessjna/java-native-accessjna_3.2.3
# Currently processing: java-native-accessjna
# Finish processing: java-native-accessjna/java-native-accessjna_3.2.3
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.8
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.8
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.7
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.7
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.6
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.6
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.5
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.5
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.4
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.4
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.3
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.3
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.2
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.2
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.1
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.1
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta5
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta5
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta4
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta4
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta3
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta3
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta2
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta2
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta1
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-beta1
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-RC2
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-RC2
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-RC1
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-RC1
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M6
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M6
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M5
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M5
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M4
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M4
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M3
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M3
# Processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M2
# Currently processing: jankotek-mapdb
# Finish processing: jankotek-mapdb/jankotek-mapdb_mapdb-3.0.0-M2
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.9.1
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.9.1
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.9
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.9
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.3
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.3
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.2
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.2
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.1
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8.1
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.8
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.7.1
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.7.1
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.7
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.7
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.6
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.6
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.5
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.5
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.4
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.4
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.35
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.35
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.34
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.34
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.33
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.33
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.32
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.32
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.31
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.31
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.30
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.30
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.3
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.3
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.29
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.29
# Processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.28
# Currently processing: izhangzhihao-intellij-rainbow-brackets
# Finish processing: izhangzhihao-intellij-rainbow-brackets/izhangzhihao-intellij-rainbow-brackets_5.28
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.5.2
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.5.2
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.5.1
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.5.1
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.5.0
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.5.0
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.4.0
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.4.0
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.3.0
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.3.0
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.2.1
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.2.1
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.2.0
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.2.0
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.1.1
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.1.1
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.1.0
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.1.0
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.9
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.9
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.8
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.8
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.7
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.7
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.6
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.6
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.4
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.4
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.3
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.3
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.25
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.25
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.24
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.24
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.22
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.22
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.21
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.21
# Processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.20
# Currently processing: ionic-team-capacitor
# Finish processing: ionic-team-capacitor/ionic-team-capacitor_1.0.0-beta.20
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.5
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.5
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.4
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.4
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.3
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.3
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.2
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.2
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.1
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.1
# Processing: immutables-immutables/immutables-immutables_immutables-2.7.0
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.7.0
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.3
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.3
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.2
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.2
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.1
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.1
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.0.alpha0
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.0.alpha0
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.0-alpha3
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.0-alpha3
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.0-alpha11
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.0-alpha11
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.0-SNAPSHOT
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.0-SNAPSHOT
# Processing: immutables-immutables/immutables-immutables_immutables-2.6.0
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.6.0
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.6
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.6
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.5
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.5
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.4
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.4
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.3
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.3
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.2
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.2
# Processing: immutables-immutables/immutables-immutables_immutables-2.5.1
# Currently processing: immutables-immutables
# Finish processing: immutables-immutables/immutables-immutables_immutables-2.5.1
# Processing: iSoron-uhabits/iSoron-uhabits_v1.8.8
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.8.8
# Processing: iSoron-uhabits/iSoron-uhabits_v1.8.7
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.8.7
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.9
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.9
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.8
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.8
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.6
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.6
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.5
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.5
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.4
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.4
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.3
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.3
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.2
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.2
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.11
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.11
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.1
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.1
# Processing: iSoron-uhabits/iSoron-uhabits_v1.7.0
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.7.0
# Processing: iSoron-uhabits/iSoron-uhabits_v1.6.2
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.6.2
# Processing: iSoron-uhabits/iSoron-uhabits_v1.6.1
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.6.1
# Processing: iSoron-uhabits/iSoron-uhabits_v1.6.0
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.6.0
# Processing: iSoron-uhabits/iSoron-uhabits_v1.5.6
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.5.6
# Processing: iSoron-uhabits/iSoron-uhabits_v1.5.5
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.5.5
# Processing: iSoron-uhabits/iSoron-uhabits_v1.5.4
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.5.4
# Processing: iSoron-uhabits/iSoron-uhabits_v1.5.3
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.5.3
# Processing: iSoron-uhabits/iSoron-uhabits_v1.5.2
# Currently processing: iSoron-uhabits
# Finish processing: iSoron-uhabits/iSoron-uhabits_v1.5.2
# Processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.9
# Currently processing: hibernate-hibernate-orm
# Finish processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.9
# Processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.8
# Currently processing: hibernate-hibernate-orm
# Finish processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.8
# Processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.7
# Currently processing: hibernate-hibernate-orm
# Finish processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.7
# Processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.6
# Currently processing: hibernate-hibernate-orm
# Finish processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.6
# Processing: hibernate-hibernate-orm/hibernate-hibernate-orm_5.4.5
# Currently processing: hibernate-hibernate-orm

# %%
from google.cloud import storage
client = storage.Client()
print("Client created using default project: {}".format(client.project))

# Replace the string below with a unique name for the new bucket
bucket_name = "software-remodularization-ck-metrics-results-individual-version"
bucket = client.get_bucket(bucket_name)

print("Bucket name: {}".format(bucket.name))
print("Bucket location: {}".format(bucket.location))
print("Bucket storage class: {}".format(bucket.storage_class))


finished_project_arr = ['web3j-web3j']

for project_name in project_releases['project_name'].unique():
    max_value_rsf = 0
    if project_name in finished_project_arr:
        current_project = pd.DataFrame(project_releases[project_releases['project_name'] == project_name])
        current_project['rank'] = current_project['version_name'].rank()
        current_project = current_project.sort_values(by=['rank'], ascending=False)

        
        for row in current_project.iterrows():
            
            print('Currently processing: ' + project_name)
            command = 'java -jar ck-0.3.3-SNAPSHOT-jar-with-dependencies.jar raw_sourcecode/' + project_name + '/' + project_name + '_' + row[1]['version_name']
            os.system(command)
            os.rename('class.csv', project_name + '_' + row[1]['version_name'] + '_class.csv')
            os.rename('field.csv',  project_name + '_' + row[1]['version_name'] + '_field.csv')
            os.rename('method.csv', project_name + '_' + row[1]['version_name'] + '_method.csv')
            
            shutil.move(project_name + '_' + row[1]['version_name'] + '_class.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_class.csv')
            shutil.move(project_name + '_' + row[1]['version_name'] + '_field.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_field.csv')
            shutil.move(project_name + '_' + row[1]['version_name'] + '_method.csv', 'ck_results_invi/' + project_name + '_' + row[1]['version_name'] + '_method.csv')

            #blob_name = project_name + '_class.csv'
            #blob = bucket.blob(blob_name)
            #source_file_name = project_name + '_class.csv'
            #blob.upload_from_filename(source_file_name)
            #print("File uploaded to {}.".format(bucket.name))

            #blob_name = project_name + '_field.csv'
            #blob = bucket.blob(blob_name)
            #source_file_name = project_name + '_field.csv'
            #blob.upload_from_filename(source_file_name)
            #print("File uploaded to {}.".format(bucket.name))

            #blob_name = project_name + '_method.csv'
            #blob = bucket.blob(blob_name)
            #source_file_name = project_name + '_method.csv'
            #blob.upload_from_filename(source_file_name)
            #print("File uploaded to {}.".format(bucket.name))

            #os.remove(project_name + '_' + row[1]['version_name'] + '_class.csv')
            #os.remove(project_name + '_' + row[1]['version_name'] + '_field.csv')
            #os.remove(project_name + '_' + row[1]['version_name'] + '_method.csv')

            #finished_project = open('finished_ck_projects.txt', 'a')
            #finished_project.write(project_name + '\n')
            #finished_project.close()

            print('Finish processing: ' + project_name + '/' + project_name + '_' + row[1]['version_name'])
# Out:
# Client created using default project: softwareremodularization
# Bucket name: software-remodularization-ck-metrics-results-individual-version
# Bucket location: US
# Bucket storage class: STANDARD
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.6.1
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.6.0-android
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.6.0
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.9
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.8
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.7
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.6
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.5
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.4
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.2
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.18
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.17
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.16
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.15
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.14
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.13
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.12
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.11
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.10
# Currently processing: web3j-web3j
# Finish processing: web3j-web3j/web3j-web3j_v4.5.1

# %%
for row in project_link.iterrows():
    project_name = row[1]['project_name']
    if project_name not in finished_project_arr:
        print('Currently processing: ' + project_name)
        command = 'java -jar ck-0.3.3-SNAPSHOT-jar-with-dependencies.jar raw_sourcecode/' + project_name
        os.system(command)
        os.rename('class.csv', project_name + '_class.csv')
        os.rename('field.csv', project_name + '_field.csv')
        os.rename('method.csv', project_name + '_method.csv')

        blob_name = project_name + '_class.csv'
        blob = bucket.blob(blob_name)
        source_file_name = project_name + '_class.csv'
        blob.upload_from_filename(source_file_name)
        #print("File uploaded to {}.".format(bucket.name))

        blob_name = project_name + '_field.csv'
        blob = bucket.blob(blob_name)
        source_file_name = project_name + '_field.csv'
        blob.upload_from_filename(source_file_name)
        #print("File uploaded to {}.".format(bucket.name))

        blob_name = project_name + '_method.csv'
        blob = bucket.blob(blob_name)
        source_file_name = project_name + '_method.csv'
        blob.upload_from_filename(source_file_name)
        #print("File uploaded to {}.".format(bucket.name))

        os.remove(project_name + '_class.csv')
        os.remove(project_name + '_field.csv')
        os.remove(project_name + '_method.csv')

        finished_project = open('finished_ck_projects.txt', 'a')
        finished_project.write(project_name + '\n')
        finished_project.close()
        
        print('Finish processing: ' + project_name)
