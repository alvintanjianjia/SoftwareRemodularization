# %%
import json
import pandas as pd
import numpy as np
import networkx as nx
import jellyfish
import os
import shutil
import subprocess
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering
from zipfile import ZipFile
from filecmp import dircmp

# %%
project_name = 'apache-log4j'
project_releases = pd.read_csv('project_links_202.csv')

# %%
project_releases.head()
# Out:
#      project_name                       project_link revision version_name
# 0  ZieIony-Carbon  https://github.com/ZieIony/Carbon  567fd84       7.1.84
# 1  ZieIony-Carbon  https://github.com/ZieIony/Carbon  9a343f5       7.1.83
# 2  ZieIony-Carbon  https://github.com/ZieIony/Carbon  a655476       7.1.82
# 3  ZieIony-Carbon  https://github.com/ZieIony/Carbon  ad84a93       7.1.81
# 4  ZieIony-Carbon  https://github.com/ZieIony/Carbon  5fa652f       7.1.80

# %%
current_project = pd.DataFrame(project_releases[project_releases['project_name'] == project_name])
current_project['rank'] = current_project['version_name'].rank()
current_project = current_project.sort_values(by=['rank'], ascending=False)
current_project.head(30)
# Out:
#       project_name                     project_link revision version_name  \
# 1071  apache-log4j  https://github.com/apache/log4j  31d7ec7        8.2.0
# 1072  apache-log4j  https://github.com/apache/log4j  fcbe46c        8.1.1
# 1073  apache-log4j  https://github.com/apache/log4j  dbe5ed0        8.1.0
# 1074  apache-log4j  https://github.com/apache/log4j  2ae4746        8.0.0
# 1075  apache-log4j  https://github.com/apache/log4j  d4c30fc        7.7.2
# 1076  apache-log4j  https://github.com/apache/log4j  5bf96d3        7.7.1
# 1077  apache-log4j  https://github.com/apache/log4j  8c831da        7.7.0
# 1078  apache-log4j  https://github.com/apache/log4j  719cde9        7.6.0
# 1079  apache-log4j  https://github.com/apache/log4j  b5bf70b        7.5.0
# 1080  apache-log4j  https://github.com/apache/log4j  9060ac6        7.4.0
# 1081  apache-log4j  https://github.com/apache/log4j  ae0705e        7.3.1
# 1082  apache-log4j  https://github.com/apache/log4j  98a6b3d        7.3.0
# 1083  apache-log4j  https://github.com/apache/log4j  b2b6438        7.2.1
# 1084  apache-log4j  https://github.com/apache/log4j  bca54ca        7.2.0
# 1085  apache-log4j  https://github.com/apache/log4j  84c90ad        7.1.0
# 1086  apache-log4j  https://github.com/apache/log4j  68fa249        6.6.6
# 1087  apache-log4j  https://github.com/apache/log4j  d29c3d1        6.6.5
# 1088  apache-log4j  https://github.com/apache/log4j  073a1fe        6.6.4
# 1089  apache-log4j  https://github.com/apache/log4j  d1e9bbd        6.6.3
# 1090  apache-log4j  https://github.com/apache/log4j  df4de29        6.6.2
# 1091  apache-log4j  https://github.com/apache/log4j  b344167        5.5.5
#
#       rank
# 1071  21.0
# 1072  20.0
# 1073  19.0
# 1074  18.0
# 1075  17.0
# 1076  16.0
# 1077  15.0
# 1078  14.0
# 1079  13.0
# 1080  12.0
# 1081  11.0
# 1082  10.0
# 1083   9.0
# 1084   8.0
# 1085   7.0
# 1086   6.0
# 1087   5.0
# 1088   4.0
# 1089   3.0
# 1090   2.0
# 1091   1.0

# %%
### Download dataset
try:
    os.mkdir('raw_sourcecode/' + project_name)
except:
    pass
for row in current_project.iterrows():
    command = 'cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/' + project_name +' & mkdir ' + project_name + '_' +row[1]['version_name']
    
    #print(command)
    os.system(command)
    
    command = 'git clone ' + row[1]['project_link'] +  ' C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/' + project_name + '/' + project_name + '_' + row[1]['version_name']
    
    print(command)
    os.system(command)
    command = 'cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/' + project_name + '/' + project_name +'_' + row[1]['version_name'] + ' & git checkout ' + row[1]['revision']
    print(command)
    os.system(command)
# Out:
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.2.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.2.0 & git checkout 31d7ec7
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.1 & git checkout fcbe46c
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.0 & git checkout dbe5ed0
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.0.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.0.0 & git checkout 2ae4746
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.2
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.2 & git checkout d4c30fc
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.1 & git checkout 5bf96d3
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.0 & git checkout 8c831da
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.6.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.6.0 & git checkout 719cde9
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.5.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.5.0 & git checkout b5bf70b
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.4.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.4.0 & git checkout 9060ac6
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.1 & git checkout ae0705e
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.0 & git checkout 98a6b3d
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.1 & git checkout b2b6438
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.0 & git checkout bca54ca
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.1.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.1.0 & git checkout 84c90ad
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.6
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.6 & git checkout 68fa249
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.5
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.5 & git checkout d29c3d1
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.4
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.4 & git checkout 073a1fe
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.3
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.3 & git checkout d1e9bbd
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.2
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.2 & git checkout df4de29
# git clone https://github.com/apache/log4j C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_5.5.5
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_5.5.5 & git checkout b344167

# %%
### Run Depends
try:
    os.mkdir('raw_depends/' + project_name)
except:
    pass
for row in current_project.iterrows():
    #command = 'cd C:/Users/tanji/Desktop/SoftwareRemodularization/raw_depends/' + project_name +' & mkdir ' + project_name + '_' +row[1]['version_name']
    #os.system(command)
    #print(command)
    command = 'cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & ' + 'java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/'  + project_name + '/' + project_name + '_' + row[1]['version_name']+  ' ../raw_depends/' + project_name + "/" + project_name + '_' + row[1]['version_name'] 
    print(command)
    os.system(command)
# Out:
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.2.0 ../raw_depends/apache-log4j/apache-log4j_8.2.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.1 ../raw_depends/apache-log4j/apache-log4j_8.1.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.1.0 ../raw_depends/apache-log4j/apache-log4j_8.1.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_8.0.0 ../raw_depends/apache-log4j/apache-log4j_8.0.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.2 ../raw_depends/apache-log4j/apache-log4j_7.7.2
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.1 ../raw_depends/apache-log4j/apache-log4j_7.7.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.7.0 ../raw_depends/apache-log4j/apache-log4j_7.7.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.6.0 ../raw_depends/apache-log4j/apache-log4j_7.6.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.5.0 ../raw_depends/apache-log4j/apache-log4j_7.5.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.4.0 ../raw_depends/apache-log4j/apache-log4j_7.4.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.1 ../raw_depends/apache-log4j/apache-log4j_7.3.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.3.0 ../raw_depends/apache-log4j/apache-log4j_7.3.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.1 ../raw_depends/apache-log4j/apache-log4j_7.2.1
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.2.0 ../raw_depends/apache-log4j/apache-log4j_7.2.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_7.1.0 ../raw_depends/apache-log4j/apache-log4j_7.1.0
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.6 ../raw_depends/apache-log4j/apache-log4j_6.6.6
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.5 ../raw_depends/apache-log4j/apache-log4j_6.6.5
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.4 ../raw_depends/apache-log4j/apache-log4j_6.6.4
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.3 ../raw_depends/apache-log4j/apache-log4j_6.6.3
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.2 ../raw_depends/apache-log4j/apache-log4j_6.6.2
# cd C:/Users/tanji/Desktop/SoftwareRemodularization/depends-0.9.2 & java -jar depends.jar java C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_5.5.5 ../raw_depends/apache-log4j/apache-log4j_5.5.5

# %%
try:
    os.mkdir('groundtruth/' + project_name)
except:
    pass

### Counter to only ensure the top 10 projects are selected
counter = 10

for row in current_project.iterrows():
    counter -= 1
    if counter < 0:
        break
    project_rank = row[1]['rank']
    #print(project_rank)
    rootdir = 'C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/' + project_name + '/' + project_name + '_' + row[1]['version_name']
    #print(rootdir)
    
    
    ### To obtain the current initial directory
    full_dir_arr = []
    for root, dirs, files in os.walk(rootdir):
        #print(root)
        #print(dirs)
        for element in files:
            if '.java' in element:
                dir_string = root + '\\' + element
                full_dir_arr.append(dir_string)

    cluster_dict = {}
    cluster_tree = {}


    for element in full_dir_arr:

        element = element.split('\\')
        i = len(element)
        while i > 1:
            #print(element[i-1])
            parent = element[i-2]
            child = element[i-1]
            #print(parent)
            #print('#')
            #print(child)
            i -= 1
            if parent in cluster_dict:
                cluster_dict[parent] += 1
            else:
                cluster_dict[parent] = 1

            cluster_tree[child] = parent
            
    current_rank = project_rank
    while current_rank >= (project_rank - 10):
        current_rank -= 1
        project_to_be_compared = current_project[current_project['rank'] == current_rank]
        project_to_be_compared_rootdir = 'C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/' + project_name + '/' + project_name + '_' + project_to_be_compared['version_name'].values[0]
        #print(project_to_be_compared_rootdir)


        ### To obtain the current initial directory
        project_to_be_compared_full_dir_arr = []
        for root, dirs, files in os.walk(project_to_be_compared_rootdir):
            #print(root)
            #print(dirs)
            for element in files:
                if '.java' in element:
                    dir_string = root + '\\' + element
                    project_to_be_compared_full_dir_arr.append(dir_string)

        project_to_be_compared_cluster_dict = {}
        project_to_be_compared_cluster_tree = {}


        for element in project_to_be_compared_full_dir_arr:

            element = element.split('\\')
            i = len(element)
            while i > 1:
                #print(element[i-1])
                parent = element[i-2]
                child = element[i-1]
                #print(parent)
                #print('#')
                #print(child)
                i -= 1
                if parent in project_to_be_compared_cluster_dict:
                    project_to_be_compared_cluster_dict[parent] += 1
                else:
                    project_to_be_compared_cluster_dict[parent] = 1

                project_to_be_compared_cluster_tree[child] = parent
                
        cluster_tree =  {x:cluster_tree[x] for x in cluster_tree if x in project_to_be_compared_cluster_tree} 
        
    filename = 'C:/Users/tanji/Desktop/SoftwareRemodularization/groundtruth/' + project_name + '/' + project_name + '_' + row[1]['version_name'] + '.txt'
    with open(filename, 'w') as f:
        for key, value in cluster_tree.items():
            f.write(value + ' contain ' + key + '\n')

# %%
with open('C:/Users/tanji/Desktop/SoftwareRemodularization/raw_depends/apache-log4j/apache-log4j_8.2.0.json') as f:
    depends_results = json.load(f)
    for element in depends_results['variables']:
        print(element)
        
    print(len(depends_results['variables']))
# Out:
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\CekiGulcu\AppenderTable.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\CekiGulcu\Transform.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\EirikLygre\DailyFileAppender1.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\JamesHouse\LogTextPanel.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\JamesHouse\LogTextPanelExample.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\JamesHouse\TextPanelAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\Jamie Tsao\JMSQueueAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\JimMoore\LoggingOutputStream.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\KevinSteppe\CompositeRollingAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\KevinSteppe\JDBCTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\KitchingSimon\DatagramStringAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\KitchingSimon\DatagramStringWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\KitchingSimon\SingleLineTracerPrintWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\LeosLiterak\TempFileAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\MarkDouglas\SocketNode2.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\MarkDouglas\SocketServer2.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\SvenReimers\gui\JListView.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\SvenReimers\gui\JTableAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\SvenReimers\gui\TextPaneAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\SvenReimers\gui\examples\TextPaneAppenderExample.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\JDBCAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\JDBCConnectionHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\JDBCIDHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\JDBCLogger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\Log4JTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\code_example1.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\ThomasFenner\code_example2.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\VolkerMentzner\HTTPRequestHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\VolkerMentzner\Log4jRequestHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\VolkerMentzner\PluggableHTTPServer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\VolkerMentzner\RootRequestHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\contribs\VolkerMentzner\UserDialogRequestHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\MyPatternLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\MyPatternParser.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\NumberCruncher.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\NumberCruncherClient.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\NumberCruncherServer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\Sort.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\SortAlgo.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\Trivial.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\customLevel\XLevel.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\InitUsingDefaultConfigurator\InitUsingDefaultConfigurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\InitUsingLog4JProperties\InitUsingLog4JProperties.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\InitUsingMultipleAppenders\InitUsingMultipleAppenders.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\InitUsingPropertiesFile\InitUsingPropertiesFile.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\InitUsingXMLPropertiesFile\InitUsingXMLPropertiesFile.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\UsingLogMonitorAdapter\CustomizedLogLevels.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\UsingLogMonitorAdapter\UsingLogMonitorAdapter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\lf5\UsingSocketAppenders\UsingSocketAppenders.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\subclass\MyLogger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\subclass\MyLoggerFactory.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\examples\subclass\MyLoggerTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Appender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\AppenderSkeleton.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\AsyncAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\BasicConfigurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Category.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\CategoryKey.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\ConsoleAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\DailyRollingFileAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\DefaultCategoryFactory.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\DefaultThrowableRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Dispatcher.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\EnhancedPatternLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\EnhancedThrowableRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\FileAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\HTMLLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Hierarchy.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Layout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Level.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\LogMF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\LogManager.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\LogSF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\LogXF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Logger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\MDC.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\NDC.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\PatternLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\Priority.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\PropertyConfigurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\ProvisionNode.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\RollingFileAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\SimpleLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\TTCCLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\WriterAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\config\PropertyGetter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\config\PropertyPrinter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\config\PropertySetter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\config\PropertySetterException.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\AbsoluteTimeDateFormat.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\AppenderAttachableImpl.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\BoundedFIFO.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\CountingQuietWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\CyclicBuffer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\DateLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\DateTimeDateFormat.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\FileWatchdog.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\FormattingInfo.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\ISO8601DateFormat.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\Loader.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\LogLog.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\MDCKeySetExtractor.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\NullEnumeration.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\OnlyOnceErrorHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\OptionConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\PatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\PatternParser.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\QuietWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\RelativeTimeDateFormat.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\SyslogQuietWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\SyslogWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\ThreadLocalMap.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\Transform.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\helpers\UtilLoggingLevel.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jdbc\JDBCAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\AbstractDynamicMBean.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\Agent.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\AppenderDynamicMBean.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\HierarchyDynamicMBean.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\LayoutDynamicMBean.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\LoggerDynamicMBean.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\jmx\MethodUnion.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\JMSAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\JMSSink.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SMTPAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SimpleSocketServer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SocketAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SocketHubAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SocketNode.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SocketServer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\SyslogAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\TelnetAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\net\ZeroConfSupport.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\nt\NTEventLogAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\DefaultRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\ObjectRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\RendererMap.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\ThreadGroupRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\jms\MessageRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\or\sax\AttributesRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\BridgePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\BridgePatternParser.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\CachedDateFormat.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\ClassNamePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\DatePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\FileDatePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\FileLocationPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\FormattingInfo.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\FullLocationPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\IntegerPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LevelPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LineLocationPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LineSeparatorPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LiteralPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LogEvent.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LoggerPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\LoggingEventPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\MessagePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\MethodLocationPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\NDCPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\NameAbbreviator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\NamePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\PatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\PatternParser.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\PropertiesPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\RelativeTimePatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\SequenceNumberPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\ThreadPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\pattern\ThrowableInformationPatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\rewrite\MapRewritePolicy.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\rewrite\PropertyRewritePolicy.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\rewrite\ReflectionRewritePolicy.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\rewrite\RewriteAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\rewrite\RewritePolicy.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\AppenderAttachable.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\Configurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\DefaultRepositorySelector.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\ErrorCode.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\ErrorHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\Filter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\HierarchyEventListener.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\LocationInfo.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\LoggerFactory.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\LoggerRepository.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\LoggingEvent.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\NOPLogger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\NOPLoggerRepository.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\NullWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\OptionHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\RendererSupport.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\RepositorySelector.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\RootCategory.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\RootLogger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\ThrowableInformation.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\ThrowableRenderer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\ThrowableRendererSupport.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\TriggeringEventEvaluator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\spi\VectorWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\DenyAllFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\ExternallyRolledFileAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\FallbackErrorHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\LevelMatchFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\LevelRangeFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\NullAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\ReloadingPropertyConfigurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\Roller.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\varia\StringMatchFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\xml\DOMConfigurator.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\xml\Log4jEntityResolver.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\xml\SAXErrorHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\xml\UnrecognizedElementHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\java\org\apache\log4j\xml\XMLLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\javadoc\org\apache\log4j\xml\examples\XMLSample.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\main\javadoc\org\apache\log4j\xml\examples\doc-files\XMLSample.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\performance\java\org\apache\log4j\performance\ListVsVector.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\performance\java\org\apache\log4j\performance\NOPWriter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\performance\java\org\apache\log4j\performance\NewVsSetLen.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\performance\java\org\apache\log4j\performance\NullAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\src\performance\java\org\apache\log4j\performance\SystemTime.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\AsyncAppenderTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\CategoryTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\CoreTestSuite.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\DRFATestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\DefaultThrowableRendererTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\EnhancedMyPatternLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\EnhancedPatternLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\EnhancedPatternLayoutTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\EnhancedThrowableRendererTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\FileAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\HTMLLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\HierarchyThresholdTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\Last.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\LayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\LevelTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\LogCapture.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\LogManagerTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\LoggerTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\MDCOrderFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\MDCTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\MinimumTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\MyPatternLayout.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\MyPatternParser.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\PatternLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\PatternLayoutTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\PriorityTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\PropertyConfiguratorTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\RFATestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\StressCategory.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\TTCCLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\TestLogMF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\TestLogSF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\TestLogXF.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\VectorAppender.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\VectorErrorHandler.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\customLogger\XLogger.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\customLogger\XLoggerTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\defaultInit\TestCase1.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\defaultInit\TestCase2.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\defaultInit\TestCase3.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\defaultInit\TestCase4.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\BoundedFIFOTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\CyclicBufferTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\DateLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\LogLogTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\OptionConverterTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\PatternParserTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\helpers\UtilLoggingLevelTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\SMTPAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\ShortSocketServer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\SocketAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\SocketServerTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\SyslogAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\net\TelnetAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\nt\NTEventLogAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\or\ORTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\pattern\CachedDateFormatTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\pattern\FormattingInfoTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\pattern\NameAbbreviatorTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\pattern\Num343PatternConverter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\pattern\PatternParserTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\rewrite\RewriteAppenderTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\spi\LocationInfoTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\spi\LoggingEventTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\spi\ThrowableInformationTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\AbsoluteDateAndTimeFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\AbsoluteTimeFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\Compare.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\ControlFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\EnhancedJunitTestRunnerFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\EnhancedLineNumberFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\Filter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\ISO8601Filter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\JunitTestRunnerFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\LineNumberFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\RelativeTimeFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\SerializationTestHelper.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\SunReflectFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\Transformer.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\UnexpectedFormatException.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\XMLLineAttributeFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\util\XMLTimestampFilter.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\varia\ERFATestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\varia\ErrorHandlerTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\varia\LevelMatchFilterTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\xml\CustomLevelTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\xml\DOMTestCase.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\xml\XLevel.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\xml\XMLLayoutTest.java
# C:\Users\tanji\Desktop\SoftwareRemodularization\raw_sourcecode\apache-log4j\apache-log4j_8.2.0\tests\src\java\org\apache\log4j\xml\XMLLayoutTestCase.java
# 309

# %%
cluster_tree
# Out:
# {'AppenderTable.java': 'CekiGulcu',
#  'CekiGulcu': 'contribs',
#  'contribs': 'C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.2',
#  'Transform.java': 'helpers',
#  'DailyFileAppender1.java': 'EirikLygre',
#  'EirikLygre': 'contribs',
#  'LogTextPanel.java': 'JamesHouse',
#  'JamesHouse': 'contribs',
#  'LogTextPanelExample.java': 'JamesHouse',
#  'TextPanelAppender.java': 'JamesHouse',
#  'JMSQueueAppender.java': 'Jamie Tsao',
#  'Jamie Tsao': 'contribs',
#  'LoggingOutputStream.java': 'JimMoore',
#  'JimMoore': 'contribs',
#  'CompositeRollingAppender.java': 'KevinSteppe',
#  'KevinSteppe': 'contribs',
#  'JDBCTest.java': 'KevinSteppe',
#  'DatagramStringAppender.java': 'KitchingSimon',
#  'KitchingSimon': 'contribs',
#  'DatagramStringWriter.java': 'KitchingSimon',
#  'SingleLineTracerPrintWriter.java': 'KitchingSimon',
#  'TempFileAppender.java': 'LeosLiterak',
#  'LeosLiterak': 'contribs',
#  'SocketNode2.java': 'MarkDouglas',
#  'MarkDouglas': 'contribs',
#  'SocketServer2.java': 'MarkDouglas',
#  'JListView.java': 'gui',
#  'gui': 'SvenReimers',
#  'SvenReimers': 'contribs',
#  'JTableAppender.java': 'gui',
#  'TextPaneAppender.java': 'gui',
#  'TextPaneAppenderExample.java': 'examples',
#  'examples': 'xml',
#  'code_example1.java': 'ThomasFenner',
#  'ThomasFenner': 'contribs',
#  'code_example2.java': 'ThomasFenner',
#  'JDBCAppender.java': 'jdbc',
#  'JDBCConnectionHandler.java': 'ThomasFenner',
#  'JDBCIDHandler.java': 'ThomasFenner',
#  'JDBCLogger.java': 'ThomasFenner',
#  'Log4JTest.java': 'ThomasFenner',
#  'HTTPRequestHandler.java': 'VolkerMentzner',
#  'VolkerMentzner': 'contribs',
#  'Log4jRequestHandler.java': 'VolkerMentzner',
#  'PluggableHTTPServer.java': 'VolkerMentzner',
#  'RootRequestHandler.java': 'VolkerMentzner',
#  'UserDialogRequestHandler.java': 'VolkerMentzner',
#  'MyPatternLayout.java': 'log4j',
#  'MyPatternParser.java': 'log4j',
#  'NumberCruncher.java': 'examples',
#  'NumberCruncherClient.java': 'examples',
#  'NumberCruncherServer.java': 'examples',
#  'Sort.java': 'examples',
#  'SortAlgo.java': 'examples',
#  'Trivial.java': 'examples',
#  'XLevel.java': 'xml',
#  'customLevel': 'examples',
#  'InitUsingDefaultConfigurator.java': 'InitUsingDefaultConfigurator',
#  'InitUsingDefaultConfigurator': 'lf5',
#  'lf5': 'examples',
#  'InitUsingLog4JProperties.java': 'InitUsingLog4JProperties',
#  'InitUsingLog4JProperties': 'lf5',
#  'InitUsingMultipleAppenders.java': 'InitUsingMultipleAppenders',
#  'InitUsingMultipleAppenders': 'lf5',
#  'InitUsingPropertiesFile.java': 'InitUsingPropertiesFile',
#  'InitUsingPropertiesFile': 'lf5',
#  'InitUsingXMLPropertiesFile.java': 'InitUsingXMLPropertiesFile',
#  'InitUsingXMLPropertiesFile': 'lf5',
#  'CustomizedLogLevels.java': 'UsingLogMonitorAdapter',
#  'UsingLogMonitorAdapter': 'lf5',
#  'UsingLogMonitorAdapter.java': 'UsingLogMonitorAdapter',
#  'UsingSocketAppenders.java': 'UsingSocketAppenders',
#  'UsingSocketAppenders': 'lf5',
#  'MyLogger.java': 'subclass',
#  'subclass': 'examples',
#  'MyLoggerFactory.java': 'subclass',
#  'MyLoggerTest.java': 'subclass',
#  'Appender.java': 'log4j',
#  'log4j': 'apache',
#  'apache': 'org',
#  'org': 'java',
#  'java': 'src',
#  'main': 'src',
#  'src': 'tests',
#  'AppenderSkeleton.java': 'log4j',
#  'AsyncAppender.java': 'log4j',
#  'BasicConfigurator.java': 'log4j',
#  'Category.java': 'log4j',
#  'CategoryKey.java': 'log4j',
#  'ConsoleAppender.java': 'log4j',
#  'DailyRollingFileAppender.java': 'log4j',
#  'DefaultCategoryFactory.java': 'log4j',
#  'DefaultThrowableRenderer.java': 'log4j',
#  'Dispatcher.java': 'log4j',
#  'EnhancedPatternLayout.java': 'log4j',
#  'EnhancedThrowableRenderer.java': 'log4j',
#  'FileAppender.java': 'log4j',
#  'Hierarchy.java': 'log4j',
#  'HTMLLayout.java': 'log4j',
#  'Layout.java': 'log4j',
#  'Level.java': 'log4j',
#  'Logger.java': 'log4j',
#  'LogManager.java': 'log4j',
#  'LogMF.java': 'log4j',
#  'LogSF.java': 'log4j',
#  'LogXF.java': 'log4j',
#  'MDC.java': 'log4j',
#  'NDC.java': 'log4j',
#  'PatternLayout.java': 'log4j',
#  'Priority.java': 'log4j',
#  'PropertyConfigurator.java': 'log4j',
#  'ProvisionNode.java': 'log4j',
#  'RollingFileAppender.java': 'log4j',
#  'SimpleLayout.java': 'log4j',
#  'TTCCLayout.java': 'log4j',
#  'WriterAppender.java': 'log4j',
#  'PropertyGetter.java': 'config',
#  'config': 'log4j',
#  'PropertyPrinter.java': 'config',
#  'PropertySetter.java': 'config',
#  'PropertySetterException.java': 'config',
#  'AbsoluteTimeDateFormat.java': 'helpers',
#  'helpers': 'log4j',
#  'AppenderAttachableImpl.java': 'helpers',
#  'BoundedFIFO.java': 'helpers',
#  'CountingQuietWriter.java': 'helpers',
#  'CyclicBuffer.java': 'helpers',
#  'DateLayout.java': 'helpers',
#  'DateTimeDateFormat.java': 'helpers',
#  'FileWatchdog.java': 'helpers',
#  'FormattingInfo.java': 'pattern',
#  'ISO8601DateFormat.java': 'helpers',
#  'Loader.java': 'helpers',
#  'LogLog.java': 'helpers',
#  'MDCKeySetExtractor.java': 'helpers',
#  'NullEnumeration.java': 'helpers',
#  'OnlyOnceErrorHandler.java': 'helpers',
#  'OptionConverter.java': 'helpers',
#  'PatternConverter.java': 'pattern',
#  'PatternParser.java': 'pattern',
#  'QuietWriter.java': 'helpers',
#  'RelativeTimeDateFormat.java': 'helpers',
#  'SyslogQuietWriter.java': 'helpers',
#  'SyslogWriter.java': 'helpers',
#  'ThreadLocalMap.java': 'helpers',
#  'UtilLoggingLevel.java': 'helpers',
#  'jdbc': 'log4j',
#  'AbstractDynamicMBean.java': 'jmx',
#  'jmx': 'log4j',
#  'Agent.java': 'jmx',
#  'AppenderDynamicMBean.java': 'jmx',
#  'HierarchyDynamicMBean.java': 'jmx',
#  'LayoutDynamicMBean.java': 'jmx',
#  'LoggerDynamicMBean.java': 'jmx',
#  'MethodUnion.java': 'jmx',
#  'JMSAppender.java': 'net',
#  'net': 'log4j',
#  'JMSSink.java': 'net',
#  'SimpleSocketServer.java': 'net',
#  'SMTPAppender.java': 'net',
#  'SocketAppender.java': 'net',
#  'SocketHubAppender.java': 'net',
#  'SocketNode.java': 'net',
#  'SocketServer.java': 'net',
#  'SyslogAppender.java': 'net',
#  'TelnetAppender.java': 'net',
#  'ZeroConfSupport.java': 'net',
#  'NTEventLogAppender.java': 'nt',
#  'nt': 'log4j',
#  'DefaultRenderer.java': 'or',
#  'or': 'log4j',
#  'ObjectRenderer.java': 'or',
#  'RendererMap.java': 'or',
#  'ThreadGroupRenderer.java': 'or',
#  'MessageRenderer.java': 'jms',
#  'jms': 'or',
#  'AttributesRenderer.java': 'sax',
#  'sax': 'or',
#  'BridgePatternConverter.java': 'pattern',
#  'pattern': 'log4j',
#  'BridgePatternParser.java': 'pattern',
#  'CachedDateFormat.java': 'pattern',
#  'ClassNamePatternConverter.java': 'pattern',
#  'DatePatternConverter.java': 'pattern',
#  'FileDatePatternConverter.java': 'pattern',
#  'FileLocationPatternConverter.java': 'pattern',
#  'FullLocationPatternConverter.java': 'pattern',
#  'IntegerPatternConverter.java': 'pattern',
#  'LevelPatternConverter.java': 'pattern',
#  'LineLocationPatternConverter.java': 'pattern',
#  'LineSeparatorPatternConverter.java': 'pattern',
#  'LiteralPatternConverter.java': 'pattern',
#  'LogEvent.java': 'pattern',
#  'LoggerPatternConverter.java': 'pattern',
#  'LoggingEventPatternConverter.java': 'pattern',
#  'MessagePatternConverter.java': 'pattern',
#  'MethodLocationPatternConverter.java': 'pattern',
#  'NameAbbreviator.java': 'pattern',
#  'NamePatternConverter.java': 'pattern',
#  'NDCPatternConverter.java': 'pattern',
#  'PropertiesPatternConverter.java': 'pattern',
#  'RelativeTimePatternConverter.java': 'pattern',
#  'SequenceNumberPatternConverter.java': 'pattern',
#  'ThreadPatternConverter.java': 'pattern',
#  'ThrowableInformationPatternConverter.java': 'pattern',
#  'MapRewritePolicy.java': 'rewrite',
#  'rewrite': 'log4j',
#  'PropertyRewritePolicy.java': 'rewrite',
#  'ReflectionRewritePolicy.java': 'rewrite',
#  'RewriteAppender.java': 'rewrite',
#  'RewritePolicy.java': 'rewrite',
#  'AppenderAttachable.java': 'spi',
#  'spi': 'log4j',
#  'Configurator.java': 'spi',
#  'DefaultRepositorySelector.java': 'spi',
#  'ErrorCode.java': 'spi',
#  'ErrorHandler.java': 'spi',
#  'Filter.java': 'util',
#  'HierarchyEventListener.java': 'spi',
#  'LocationInfo.java': 'spi',
#  'LoggerFactory.java': 'spi',
#  'LoggerRepository.java': 'spi',
#  'LoggingEvent.java': 'spi',
#  'NOPLogger.java': 'spi',
#  'NOPLoggerRepository.java': 'spi',
#  'NullWriter.java': 'spi',
#  'OptionHandler.java': 'spi',
#  'RendererSupport.java': 'spi',
#  'RepositorySelector.java': 'spi',
#  'RootCategory.java': 'spi',
#  'RootLogger.java': 'spi',
#  'ThrowableInformation.java': 'spi',
#  'ThrowableRenderer.java': 'spi',
#  'ThrowableRendererSupport.java': 'spi',
#  'TriggeringEventEvaluator.java': 'spi',
#  'VectorWriter.java': 'spi',
#  'DenyAllFilter.java': 'varia',
#  'varia': 'log4j',
#  'ExternallyRolledFileAppender.java': 'varia',
#  'FallbackErrorHandler.java': 'varia',
#  'LevelMatchFilter.java': 'varia',
#  'LevelRangeFilter.java': 'varia',
#  'NullAppender.java': 'performance',
#  'ReloadingPropertyConfigurator.java': 'varia',
#  'Roller.java': 'varia',
#  'StringMatchFilter.java': 'varia',
#  'DOMConfigurator.java': 'xml',
#  'xml': 'log4j',
#  'Log4jEntityResolver.java': 'xml',
#  'SAXErrorHandler.java': 'xml',
#  'UnrecognizedElementHandler.java': 'xml',
#  'XMLLayout.java': 'xml',
#  'XMLSample.java': 'doc-files',
#  'javadoc': 'main',
#  'doc-files': 'examples',
#  'ListVsVector.java': 'performance',
#  'performance': 'src',
#  'NewVsSetLen.java': 'performance',
#  'NOPWriter.java': 'performance',
#  'SystemTime.java': 'performance',
#  'AsyncAppenderTestCase.java': 'log4j',
#  'tests': 'C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_6.6.2',
#  'CategoryTest.java': 'log4j',
#  'CoreTestSuite.java': 'log4j',
#  'DefaultThrowableRendererTest.java': 'log4j',
#  'DRFATestCase.java': 'log4j',
#  'EnhancedMyPatternLayout.java': 'log4j',
#  'EnhancedPatternLayoutTest.java': 'log4j',
#  'EnhancedPatternLayoutTestCase.java': 'log4j',
#  'EnhancedThrowableRendererTest.java': 'log4j',
#  'FileAppenderTest.java': 'log4j',
#  'HierarchyThresholdTestCase.java': 'log4j',
#  'HTMLLayoutTest.java': 'log4j',
#  'Last.java': 'log4j',
#  'LayoutTest.java': 'log4j',
#  'LevelTest.java': 'log4j',
#  'LogCapture.java': 'log4j',
#  'LoggerTestCase.java': 'log4j',
#  'LogManagerTest.java': 'log4j',
#  'MDCOrderFilter.java': 'log4j',
#  'MDCTestCase.java': 'log4j',
#  'MinimumTestCase.java': 'log4j',
#  'PatternLayoutTest.java': 'log4j',
#  'PatternLayoutTestCase.java': 'log4j',
#  'PriorityTest.java': 'log4j',
#  'PropertyConfiguratorTest.java': 'log4j',
#  'RFATestCase.java': 'log4j',
#  'StressCategory.java': 'log4j',
#  'TestLogMF.java': 'log4j',
#  'TestLogSF.java': 'log4j',
#  'TestLogXF.java': 'log4j',
#  'TTCCLayoutTest.java': 'log4j',
#  'VectorAppender.java': 'log4j',
#  'VectorErrorHandler.java': 'log4j',
#  'XLogger.java': 'customLogger',
#  'customLogger': 'log4j',
#  'XLoggerTestCase.java': 'customLogger',
#  'TestCase1.java': 'defaultInit',
#  'defaultInit': 'log4j',
#  'TestCase2.java': 'defaultInit',
#  'TestCase3.java': 'defaultInit',
#  'TestCase4.java': 'defaultInit',
#  'BoundedFIFOTestCase.java': 'helpers',
#  'CyclicBufferTestCase.java': 'helpers',
#  'DateLayoutTest.java': 'helpers',
#  'LogLogTest.java': 'helpers',
#  'OptionConverterTestCase.java': 'helpers',
#  'PatternParserTestCase.java': 'helpers',
#  'UtilLoggingLevelTest.java': 'helpers',
#  'ShortSocketServer.java': 'net',
#  'SMTPAppenderTest.java': 'net',
#  'SocketAppenderTest.java': 'net',
#  'SocketServerTestCase.java': 'net',
#  'SyslogAppenderTest.java': 'net',
#  'TelnetAppenderTest.java': 'net',
#  'NTEventLogAppenderTest.java': 'nt',
#  'ORTestCase.java': 'or',
#  'CachedDateFormatTest.java': 'pattern',
#  'FormattingInfoTest.java': 'pattern',
#  'NameAbbreviatorTest.java': 'pattern',
#  'Num343PatternConverter.java': 'pattern',
#  'PatternParserTest.java': 'pattern',
#  'RewriteAppenderTest.java': 'rewrite',
#  'LocationInfoTest.java': 'spi',
#  'LoggingEventTest.java': 'spi',
#  'ThrowableInformationTest.java': 'spi',
#  'AbsoluteDateAndTimeFilter.java': 'util',
#  'util': 'log4j',
#  'AbsoluteTimeFilter.java': 'util',
#  'Compare.java': 'util',
#  'ControlFilter.java': 'util',
#  'EnhancedJunitTestRunnerFilter.java': 'util',
#  'EnhancedLineNumberFilter.java': 'util',
#  'ISO8601Filter.java': 'util',
#  'JunitTestRunnerFilter.java': 'util',
#  'LineNumberFilter.java': 'util',
#  'RelativeTimeFilter.java': 'util',
#  'SerializationTestHelper.java': 'util',
#  'SunReflectFilter.java': 'util',
#  'Transformer.java': 'util',
#  'UnexpectedFormatException.java': 'util',
#  'XMLLineAttributeFilter.java': 'util',
#  'XMLTimestampFilter.java': 'util',
#  'ERFATestCase.java': 'varia',
#  'ErrorHandlerTestCase.java': 'varia',
#  'LevelMatchFilterTestCase.java': 'varia',
#  'CustomLevelTestCase.java': 'xml',
#  'DOMTestCase.java': 'xml',
#  'XMLLayoutTest.java': 'xml',
#  'XMLLayoutTestCase.java': 'xml'}

# %%
cluster_tree.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-f7a0e1f693c5> in <module>
# ----> 1 cluster_tree.type
#
# AttributeError: 'dict' object has no attribute 'type'

# %%
for key, value in cluster_tree.items():
    print(value + ' contain ' + key)
# Out:
# CekiGulcu contain AppenderTable.java
# contribs contain CekiGulcu
# C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_5.5.5 contain contribs
# helpers contain Transform.java
# EirikLygre contain DailyFileAppender1.java
# contribs contain EirikLygre
# JamesHouse contain LogTextPanel.java
# contribs contain JamesHouse
# JamesHouse contain LogTextPanelExample.java
# JamesHouse contain TextPanelAppender.java
# Jamie Tsao contain JMSQueueAppender.java
# contribs contain Jamie Tsao
# JimMoore contain LoggingOutputStream.java
# contribs contain JimMoore
# KevinSteppe contain CompositeRollingAppender.java
# contribs contain KevinSteppe
# KevinSteppe contain JDBCTest.java
# KitchingSimon contain DatagramStringAppender.java
# contribs contain KitchingSimon
# KitchingSimon contain DatagramStringWriter.java
# KitchingSimon contain SingleLineTracerPrintWriter.java
# LeosLiterak contain TempFileAppender.java
# contribs contain LeosLiterak
# MarkDouglas contain SocketNode2.java
# contribs contain MarkDouglas
# MarkDouglas contain SocketServer2.java
# gui contain JListView.java
# SvenReimers contain gui
# contribs contain SvenReimers
# gui contain JTableAppender.java
# gui contain TextPaneAppender.java
# examples contain TextPaneAppenderExample.java
# xml contain examples
# ThomasFenner contain code_example1.java
# contribs contain ThomasFenner
# ThomasFenner contain code_example2.java
# jdbc contain JDBCAppender.java
# ThomasFenner contain JDBCConnectionHandler.java
# ThomasFenner contain JDBCIDHandler.java
# ThomasFenner contain JDBCLogger.java
# ThomasFenner contain Log4JTest.java
# VolkerMentzner contain HTTPRequestHandler.java
# contribs contain VolkerMentzner
# VolkerMentzner contain Log4jRequestHandler.java
# VolkerMentzner contain PluggableHTTPServer.java
# VolkerMentzner contain RootRequestHandler.java
# VolkerMentzner contain UserDialogRequestHandler.java
# log4j contain MyPatternLayout.java
# log4j contain MyPatternParser.java
# examples contain NumberCruncher.java
# examples contain NumberCruncherClient.java
# examples contain NumberCruncherServer.java
# examples contain Sort.java
# examples contain SortAlgo.java
# examples contain Trivial.java
# xml contain XLevel.java
# examples contain customLevel
# InitUsingDefaultConfigurator contain InitUsingDefaultConfigurator.java
# lf5 contain InitUsingDefaultConfigurator
# examples contain lf5
# InitUsingLog4JProperties contain InitUsingLog4JProperties.java
# lf5 contain InitUsingLog4JProperties
# InitUsingMultipleAppenders contain InitUsingMultipleAppenders.java
# lf5 contain InitUsingMultipleAppenders
# InitUsingPropertiesFile contain InitUsingPropertiesFile.java
# lf5 contain InitUsingPropertiesFile
# InitUsingXMLPropertiesFile contain InitUsingXMLPropertiesFile.java
# lf5 contain InitUsingXMLPropertiesFile
# UsingLogMonitorAdapter contain CustomizedLogLevels.java
# lf5 contain UsingLogMonitorAdapter
# UsingLogMonitorAdapter contain UsingLogMonitorAdapter.java
# UsingSocketAppenders contain UsingSocketAppenders.java
# lf5 contain UsingSocketAppenders
# subclass contain MyLogger.java
# examples contain subclass
# subclass contain MyLoggerFactory.java
# subclass contain MyLoggerTest.java
# log4j contain Appender.java
# apache contain log4j
# org contain apache
# java contain org
# src contain java
# src contain main
# tests contain src
# log4j contain AppenderSkeleton.java
# log4j contain AsyncAppender.java
# log4j contain BasicConfigurator.java
# log4j contain Category.java
# log4j contain CategoryKey.java
# log4j contain ConsoleAppender.java
# log4j contain DailyRollingFileAppender.java
# log4j contain DefaultCategoryFactory.java
# log4j contain DefaultThrowableRenderer.java
# log4j contain Dispatcher.java
# log4j contain EnhancedPatternLayout.java
# log4j contain EnhancedThrowableRenderer.java
# log4j contain FileAppender.java
# log4j contain Hierarchy.java
# log4j contain HTMLLayout.java
# log4j contain Layout.java
# log4j contain Level.java
# log4j contain Logger.java
# log4j contain LogManager.java
# log4j contain LogMF.java
# log4j contain LogSF.java
# log4j contain LogXF.java
# log4j contain MDC.java
# log4j contain NDC.java
# log4j contain PatternLayout.java
# log4j contain Priority.java
# log4j contain PropertyConfigurator.java
# log4j contain ProvisionNode.java
# log4j contain RollingFileAppender.java
# log4j contain SimpleLayout.java
# log4j contain TTCCLayout.java
# log4j contain WriterAppender.java
# config contain PropertyGetter.java
# log4j contain config
# config contain PropertyPrinter.java
# config contain PropertySetter.java
# config contain PropertySetterException.java
# helpers contain AbsoluteTimeDateFormat.java
# log4j contain helpers
# helpers contain AppenderAttachableImpl.java
# helpers contain BoundedFIFO.java
# helpers contain CountingQuietWriter.java
# helpers contain CyclicBuffer.java
# helpers contain DateLayout.java
# helpers contain DateTimeDateFormat.java
# helpers contain FileWatchdog.java
# pattern contain FormattingInfo.java
# helpers contain ISO8601DateFormat.java
# helpers contain Loader.java
# helpers contain LogLog.java
# helpers contain MDCKeySetExtractor.java
# helpers contain NullEnumeration.java
# helpers contain OnlyOnceErrorHandler.java
# helpers contain OptionConverter.java
# pattern contain PatternConverter.java
# pattern contain PatternParser.java
# helpers contain QuietWriter.java
# helpers contain RelativeTimeDateFormat.java
# helpers contain SyslogQuietWriter.java
# helpers contain SyslogWriter.java
# helpers contain ThreadLocalMap.java
# helpers contain UtilLoggingLevel.java
# log4j contain jdbc
# jmx contain AbstractDynamicMBean.java
# log4j contain jmx
# jmx contain Agent.java
# jmx contain AppenderDynamicMBean.java
# jmx contain HierarchyDynamicMBean.java
# jmx contain LayoutDynamicMBean.java
# jmx contain LoggerDynamicMBean.java
# jmx contain MethodUnion.java
# net contain JMSAppender.java
# log4j contain net
# net contain JMSSink.java
# net contain SimpleSocketServer.java
# net contain SMTPAppender.java
# net contain SocketAppender.java
# net contain SocketHubAppender.java
# net contain SocketNode.java
# net contain SocketServer.java
# net contain SyslogAppender.java
# net contain TelnetAppender.java
# net contain ZeroConfSupport.java
# nt contain NTEventLogAppender.java
# log4j contain nt
# or contain DefaultRenderer.java
# log4j contain or
# or contain ObjectRenderer.java
# or contain RendererMap.java
# or contain ThreadGroupRenderer.java
# jms contain MessageRenderer.java
# or contain jms
# sax contain AttributesRenderer.java
# or contain sax
# pattern contain BridgePatternConverter.java
# log4j contain pattern
# pattern contain BridgePatternParser.java
# pattern contain CachedDateFormat.java
# pattern contain ClassNamePatternConverter.java
# pattern contain DatePatternConverter.java
# pattern contain FileDatePatternConverter.java
# pattern contain FileLocationPatternConverter.java
# pattern contain FullLocationPatternConverter.java
# pattern contain IntegerPatternConverter.java
# pattern contain LevelPatternConverter.java
# pattern contain LineLocationPatternConverter.java
# pattern contain LineSeparatorPatternConverter.java
# pattern contain LiteralPatternConverter.java
# pattern contain LogEvent.java
# pattern contain LoggerPatternConverter.java
# pattern contain LoggingEventPatternConverter.java
# pattern contain MessagePatternConverter.java
# pattern contain MethodLocationPatternConverter.java
# pattern contain NameAbbreviator.java
# pattern contain NamePatternConverter.java
# pattern contain NDCPatternConverter.java
# pattern contain PropertiesPatternConverter.java
# pattern contain RelativeTimePatternConverter.java
# pattern contain SequenceNumberPatternConverter.java
# pattern contain ThreadPatternConverter.java
# pattern contain ThrowableInformationPatternConverter.java
# rewrite contain MapRewritePolicy.java
# log4j contain rewrite
# rewrite contain PropertyRewritePolicy.java
# rewrite contain ReflectionRewritePolicy.java
# rewrite contain RewriteAppender.java
# rewrite contain RewritePolicy.java
# spi contain AppenderAttachable.java
# log4j contain spi
# spi contain Configurator.java
# spi contain DefaultRepositorySelector.java
# spi contain ErrorCode.java
# spi contain ErrorHandler.java
# util contain Filter.java
# spi contain HierarchyEventListener.java
# spi contain LocationInfo.java
# spi contain LoggerFactory.java
# spi contain LoggerRepository.java
# spi contain LoggingEvent.java
# spi contain NOPLogger.java
# spi contain NOPLoggerRepository.java
# spi contain NullWriter.java
# spi contain OptionHandler.java
# spi contain RendererSupport.java
# spi contain RepositorySelector.java
# spi contain RootCategory.java
# spi contain RootLogger.java
# spi contain ThrowableInformation.java
# spi contain ThrowableRenderer.java
# spi contain ThrowableRendererSupport.java
# spi contain TriggeringEventEvaluator.java
# spi contain VectorWriter.java
# varia contain DenyAllFilter.java
# log4j contain varia
# varia contain ExternallyRolledFileAppender.java
# varia contain FallbackErrorHandler.java
# varia contain LevelMatchFilter.java
# varia contain LevelRangeFilter.java
# performance contain NullAppender.java
# varia contain ReloadingPropertyConfigurator.java
# varia contain Roller.java
# varia contain StringMatchFilter.java
# xml contain DOMConfigurator.java
# log4j contain xml
# xml contain Log4jEntityResolver.java
# xml contain SAXErrorHandler.java
# xml contain UnrecognizedElementHandler.java
# xml contain XMLLayout.java
# doc-files contain XMLSample.java
# main contain javadoc
# examples contain doc-files
# performance contain ListVsVector.java
# src contain performance
# performance contain NewVsSetLen.java
# performance contain NOPWriter.java
# performance contain SystemTime.java
# log4j contain AsyncAppenderTestCase.java
# C:/Users/tanji/Desktop/SoftwareRemodularization/raw_sourcecode/apache-log4j/apache-log4j_5.5.5 contain tests
# log4j contain CategoryTest.java
# log4j contain CoreTestSuite.java
# log4j contain DefaultThrowableRendererTest.java
# log4j contain DRFATestCase.java
# log4j contain EnhancedMyPatternLayout.java
# log4j contain EnhancedPatternLayoutTest.java
# log4j contain EnhancedPatternLayoutTestCase.java
# log4j contain EnhancedThrowableRendererTest.java
# log4j contain FileAppenderTest.java
# log4j contain HierarchyThresholdTestCase.java
# log4j contain HTMLLayoutTest.java
# log4j contain Last.java
# log4j contain LayoutTest.java
# log4j contain LevelTest.java
# log4j contain LogCapture.java
# log4j contain LoggerTestCase.java
# log4j contain LogManagerTest.java
# log4j contain MDCOrderFilter.java
# log4j contain MDCTestCase.java
# log4j contain MinimumTestCase.java
# log4j contain PatternLayoutTest.java
# log4j contain PatternLayoutTestCase.java
# log4j contain PriorityTest.java
# log4j contain PropertyConfiguratorTest.java
# log4j contain RFATestCase.java
# log4j contain StressCategory.java
# log4j contain TestLogMF.java
# log4j contain TestLogSF.java
# log4j contain TestLogXF.java
# log4j contain TTCCLayoutTest.java
# log4j contain VectorAppender.java
# log4j contain VectorErrorHandler.java
# customLogger contain XLogger.java
# log4j contain customLogger
# customLogger contain XLoggerTestCase.java
# defaultInit contain TestCase1.java
# log4j contain defaultInit
# defaultInit contain TestCase2.java
# defaultInit contain TestCase3.java
# defaultInit contain TestCase4.java
# helpers contain BoundedFIFOTestCase.java
# helpers contain CyclicBufferTestCase.java
# helpers contain DateLayoutTest.java
# helpers contain LogLogTest.java
# helpers contain OptionConverterTestCase.java
# helpers contain PatternParserTestCase.java
# helpers contain UtilLoggingLevelTest.java
# net contain ShortSocketServer.java
# net contain SMTPAppenderTest.java
# net contain SocketAppenderTest.java
# net contain SocketServerTestCase.java
# net contain SyslogAppenderTest.java
# net contain TelnetAppenderTest.java
# nt contain NTEventLogAppenderTest.java
# or contain ORTestCase.java
# pattern contain CachedDateFormatTest.java
# pattern contain FormattingInfoTest.java
# pattern contain NameAbbreviatorTest.java
# pattern contain Num343PatternConverter.java
# pattern contain PatternParserTest.java
# rewrite contain RewriteAppenderTest.java
# spi contain LocationInfoTest.java
# spi contain LoggingEventTest.java
# spi contain ThrowableInformationTest.java
# util contain AbsoluteDateAndTimeFilter.java
# log4j contain util
# util contain AbsoluteTimeFilter.java
# util contain Compare.java
# util contain ControlFilter.java
# util contain EnhancedJunitTestRunnerFilter.java
# util contain EnhancedLineNumberFilter.java
# util contain ISO8601Filter.java
# util contain JunitTestRunnerFilter.java
# util contain LineNumberFilter.java
# util contain RelativeTimeFilter.java
# util contain SerializationTestHelper.java
# util contain SunReflectFilter.java
# util contain Transformer.java
# util contain UnexpectedFormatException.java
# util contain XMLLineAttributeFilter.java
# util contain XMLTimestampFilter.java
# varia contain ERFATestCase.java
# varia contain ErrorHandlerTestCase.java
# varia contain LevelMatchFilterTestCase.java
# xml contain CustomLevelTestCase.java
# xml contain DOMTestCase.java
# xml contain XMLLayoutTest.java
# xml contain XMLLayoutTestCase.java
