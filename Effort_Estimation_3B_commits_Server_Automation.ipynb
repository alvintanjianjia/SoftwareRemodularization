# %%
import papermill as pm

pm.execute_notebook(
   'Effort_Estimation_3B_commits_Server.ipynb',
   'Automation_Output.ipynb',
   parameters = dict(project_owner='traccar', project_name_short='traccar', ckmetrics_filename='Traccar')
)
# Out:
# Executing:   0%|          | 0/36 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'scrolled': False,
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-01-04T14:16:06.373939',
#      'end_time': '2022-01-04T14:16:08.099033',
#      'duration': 1.725094,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2022-01-04T14:16:06.390938Z',
#      'iopub.execute_input': '2022-01-04T14:16:06.391964Z',
#      'iopub.status.idle': '2022-01-04T14:16:08.098031Z',
#      'shell.execute_reply': '2022-01-04T14:16:08.099033Z'}},
#    'outputs': [],
# ...
