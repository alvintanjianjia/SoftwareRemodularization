# %%
from github import Github
import pandas as pd
import os
from distutils.version import LooseVersion
import numpy
from datetime import datetime
import time
import psycopg2

# %%
old_links = pd.read_csv('project_links_202_old.csv')
old_links.head()
# Out:
#      project_name                       project_link revision version_name
# 0  ZieIony-Carbon  https://github.com/ZieIony/Carbon  567fd84       7.1.84
# 1  ZieIony-Carbon  https://github.com/ZieIony/Carbon  9a343f5       7.1.83
# 2  ZieIony-Carbon  https://github.com/ZieIony/Carbon  a655476       7.1.82
# 3  ZieIony-Carbon  https://github.com/ZieIony/Carbon  ad84a93       7.1.81
# 4  ZieIony-Carbon  https://github.com/ZieIony/Carbon  5fa652f       7.1.80

# %%
unique_project_links = old_links[['project_name', 'project_link']]
unique_project_links = unique_project_links.drop_duplicates()
unique_project_links.head()
# Out:
#              project_name                              project_link
# 0          ZieIony-Carbon         https://github.com/ZieIony/Carbon
# 21      activiti-activiti      https://github.com/Activiti/Activiti
# 42  airbnb-lottie-android  https://github.com/airbnb/lottie-android
# 63       alibaba-fastjson       https://github.com/alibaba/fastjson
# 84       alibaba-jetcache       https://github.com/alibaba/jetcache

# %%
g = Github('tanjianjia@gmail.com', 'd8158219bffa0cd3371a9fb237289e30d6402de1', timeout=3000)

# %%
main_arr = []
for row in unique_project_links.iterrows():
    try:
        repo = g.get_repo(row[1]['project_link'].replace('https://github.com/',''))
        counter = 22
        for release in repo.get_tags():
            temp_arr = []
            if counter > 0:
                temp_arr.append(row[1]['project_name'])
                temp_arr.append(row[1]['project_link'])
                temp_arr.append(release.name)
                temp_arr.append(release.commit)
                main_arr.append(temp_arr)
                counter -= 1
            else:
                break
        print(row[1]['project_name'], 'Success')
    except:
        print(row[1]['project_name'], 'Error')
# Out:
# ZieIony-Carbon Success
# activiti-activiti Success
# airbnb-lottie-android Success
# alibaba-fastjson Success
# alibaba-jetcache Success
# androidannotations-androidannotations Success
# apache-activemq-artemis Success
# apache-activemq Success
# apache-ambari Error
# apache-archiva Success
# apache-avro Success
# apache-beam Success
# apache-bookkeeper Success
# apache-calcite Success
# apache-camel Success
# apache-cassandra Success
# apache-cloudstack Success
# apache-commons-lang Success
# apache-commons-math Success
# apache-commons-net Success
# apache-commons-pool Success
# apache-cordova-android Success
# apache-cordova-docs Success
# apache-curator Success
# apache-cxf Success
# apache-deltaspike Success
# apache-directory-ldap-api Success
# apache-drill Success
# apache-dubbo Success
# apache-flink Success
# apache-groovy Success
# apache-hadoop Success
# apache-hbase Success
# apache-hive Success
# apache-httpcomponents-core Success
# apache-ignite Success
# apache-incubator-datasketches-java Success
# apache-incubator-druid Success
# apache-incubator-hudi Error
# apache-isis Success
# apache-jackrabbit-filevault Success
# apache-jackrabbit-oak Success
# apache-jclouds Success
# apache-jena Success
# apache-jmeter Success
# apache-johnzon Success
# apache-jspwiki Success
# apache-kafka Success
# apache-karaf Success
# apache-kylin Success
# apache-log4j Success
# apache-lucene-solr Success
# apache-mahout Success
# apache-maven-compiler-plugin Success
# apache-maven-site-plugin Success
# apache-maven-surefire Success
# apache-maven Success
# apache-metamodel Success
# apache-mina-sshd Success
# apache-myfaces Success
# apache-nifi Success
# apache-nutch Success
# apache-oodt Success
# apache-openmeetings Success
# apache-openwebbeans Success
# apache-parquet-mr Success
# apache-pulsar Success
# apache-qpid-broker-j Success
# apache-qpid-jms Success
# apache-roller Success
# apache-sling-org-apache-sling-event Success
# apache-sling-org-apache-sling-resourceresolver Success
# apache-sling-org-apache-sling-scripting-jsp Success
# apache-sling-org-apache-sling-testing-sling-mock Success
# apache-spark Success
# apache-storm Success
# apache-struts Success
# apache-syncope Success
# apache-tapestry-5 Success
# apache-tika Success
# apache-tinkerpop Success
# apache-tomcat Success
# apache-tomee Error
# apache-uima-uimaj Success
# apache-wicket Success
# apacheaccumulo Success
# auth0-java-jwt Success
# aws-aws-sdk-java-v2 Success
# aws-aws-sdk-java Success
# bdew-neiaddons Success
# bkromhout-realm-java Success
# bkromhout-realm-recyclerview-lite Success
# btraceio-btrace Success
# bumptech-glide Success
# bytedeco-javacpp Success
# cglib-cglib Success
# checkstyle-checkstyle Success
# codecentric-spring-boot-admin Success
# codenvy-legacy-che-plugins Success
# coobird-thumbnailator Success
# crate-crate Success
# cryptomator-cryptomator Success
# culturecommunication-ginco Success
# dropwizard-dropwizard Success
# dropwizard-metrics Success
# elastic-elasticsearch Error
# evant-gradle-retrolambda Success
# facebook-buck Success
# facebook-facebook-android-sdk Success
# facebook-facebook-java-business-sdk Success
# facebook-fresco Success
# facebook-litho Success
# facebook-react-native-fbsdk Success
# facebook-robolectric Success
# Flow86-Additional-Buildcraft-Objects-Mod Success
# flyway_flyway Success
# fullwall-Citizens Success
# google-cdep Success
# google-dagger Success
# google-error-prone-javac Success
# google-error-prone Success
# google-exoplayer Success
# google-gitiles Success
# google-gson Success
# google-guava Success
# google-j2objc Success
# google-openrtb-doubleclick Success
# google-openrtb Success
# google-truth Success
# grpc-grpc-java Success
# havarunner-havarunner Success
# hazelcast-hazelcast Success
# hibernate-hibernate-orm Success
# immutables-immutables Success
# ionic-team-capacitor Success
# iSoron-uhabits Success
# izhangzhihao-intellij-rainbow-brackets Success
# jakewharton-butterknife Success
# jankotek-mapdb Success
# java-native-accessjna Success
# javafunk-funk Success
# javaparser-javaparser Success
# jboss-switchyard-quickstarts Error
# jboss-switchyard-release Success
# jenkinsci-jenkins Success
# jhy-jsoup Success
# JodaOrg-joda-time Success
# joelittlejohn-jsonschema2pojo Success
# Jotschi-maven-release-workflow-test Success
# kijiproject-kiji-bento Success
# kijiproject-kiji-schema Error
# knowm-XChange Success
# lettuce-io-lettuce-core Success
# mockito-mockito Success
# mrniko-netty-socketio Success
# mybatis-mybatis-3 Success
# naver-pinpoint Success
# netty-netty Success
# oblac-jodd Success
# oharaandrew314-TinkerTime Error
# openengsb-openengsb Success
# oracle-helidon Success
# oracle-oci-java-sdk Success
# oracle-opengrok Success
# oracle-spacewalk-backend Success
# oracle-spacewalk-java Success
# oracle-spacewalk-schema Success
# oracle-spacewalk-selinux Success
# oracle-spacewalk-utils Success
# permissions-dispatcher-PermissionsDispatcher Success
# pmd-pmd Success
# prolificinteractive-material-calendarview Success
# pxb1988-dex2jar Success
# quarkusio-quarkus Success
# querydsl-querydsl Success
# raphw-byte-buddy Success
# ReactiveX-RxJava Success
# real-logic-aeron Success
# realm-realm-java Success
# redisson-redisson Success
# rest-assured-rest-assured Success
# robolectric-robolectric Success
# rzwitserloot-lombok Success
# scribejava-scribejava Success
# seleniumHQ-selenium Success
# simplegeo-java-simplegeo Success
# socketio-socket.io-client-java Success
# sofastack-sofa-rpc Success
# spring-projects-spring-boot Success
# spring-projects-spring-security Success
# springfox-springfox Success
# square-android-times-square Success
# square-okhttp Success
# square-retrofit Success
# square-wire Success
# swagger-api-swagger-core Success
# testcontainers-testcontainers-java Success
# Twitter4J-Twitter4J Success
# uber-NullAway Success
# voxeolabs-moho Success
# web3j-web3j Success

# %%
new_links = pd.DataFrame(main_arr)
new_links.columns = ['project_name', 'project_link', 'version_name', 'commit']

# %%
print(len(new_links['project_name'].unique()))
# Out:
# 194

# %%
new_links.head()
# Out:
#      project_name                       project_link version_name  \
# 0  ZieIony-Carbon  https://github.com/ZieIony/Carbon       0.11.0
# 1  ZieIony-Carbon  https://github.com/ZieIony/Carbon       0.10.1
# 2  ZieIony-Carbon  https://github.com/ZieIony/Carbon     0.10.0.1
# 3  ZieIony-Carbon  https://github.com/ZieIony/Carbon       0.10.0
# 4  ZieIony-Carbon  https://github.com/ZieIony/Carbon        0.9.0
#
#                                               commit
# 0  Commit(sha="7cabd4681b18d88ffa27a848ed76655063...
# 1  Commit(sha="68b770b148fe364b701e3d2d4bbfec6e83...
# 2  Commit(sha="d6a17ed24c096919cf9f55eecd93a04923...
# 3  Commit(sha="81b12fa328b86feb517a97bf575528c2f3...
# 4  Commit(sha="16ff8ae087e804cd3d5904d55891ace032...

# %%
for row in new_links.iterrows():
    print(row[1]['commit'])

# %%
new_links.to_csv('project_links_194_new.csv',index=False)

# %%
repo = g.get_repo(unique_project_links[0].replace('https://github.com/',''))
arr = 
for release in repo.get_tags():
    print(release)
    print(release.name)
    arr.append()
# Out:
# Tag(name="0.11.0", commit=Commit(sha="7cabd4681b18d88ffa27a848ed76655063d5371a"))
# 0.11.0
# Tag(name="0.10.1", commit=Commit(sha="68b770b148fe364b701e3d2d4bbfec6e83e850ca"))
# 0.10.1
# Tag(name="0.10.0.1", commit=Commit(sha="d6a17ed24c096919cf9f55eecd93a049231a2754"))
# 0.10.0.1
# Tag(name="0.10.0", commit=Commit(sha="81b12fa328b86feb517a97bf575528c2f3c9b8e6"))
# 0.10.0
# Tag(name="0.9.0", commit=Commit(sha="16ff8ae087e804cd3d5904d55891ace032131521"))
# 0.9.0
# Tag(name="0.8.0", commit=Commit(sha="77a0f3a18b1cfcd8d921d4e07e387f25edfea1ba"))
# 0.8.0
# Tag(name="0.7.4", commit=Commit(sha="f9e613fcf8a6132e6dd954b75b15fc94be8a9890"))
# 0.7.4
# Tag(name="0.7.3", commit=Commit(sha="ce85ed49e9ca8edfe2908db5b9d8a9eb0f176a3d"))
# 0.7.3
# Tag(name="0.7.2", commit=Commit(sha="04703508590dbe997c0ef5666e37b864478df43a"))
# 0.7.2
# Tag(name="0.7.1", commit=Commit(sha="f16a04468e36784228a38e9137b5665d8ad1fc8b"))
# 0.7.1
# Tag(name="0.7.0", commit=Commit(sha="c7afea931e5e9ea63866e773551602c0a6423269"))
# 0.7.0
# Tag(name="0.6.7.2", commit=Commit(sha="adf12c5e5818a344e7ab9f8c3c726f4f1613e9a5"))
# 0.6.7.2
# Tag(name="0.6.7.1", commit=Commit(sha="ba16d8f59f37243e401cce46ca3a14486a349b7c"))
# 0.6.7.1
# Tag(name="0.6.7", commit=Commit(sha="2fcf4e2e18f2aa151a938af0d67dfbec731619af"))
# 0.6.7
# Tag(name="0.6.6", commit=Commit(sha="3c0875f4222f76816cd5c1a173bc3c7fb83ca5db"))
# 0.6.6
# Tag(name="0.6.5", commit=Commit(sha="64e53843103b0f32834d2be111cc7e45eabc28fe"))
# 0.6.5
# Tag(name="0.6.4", commit=Commit(sha="d444574cc2aed140c5e2a109b0c8e1585b0c85e3"))
# 0.6.4
# Tag(name="0.6.3.1", commit=Commit(sha="c4f6fec20d1728bbe4057a91798a85060ec12831"))
# 0.6.3.1
# Tag(name="0.6.3", commit=Commit(sha="310d16c0d50fbe3a138349b544c0c86e94213d22"))
# 0.6.3
# Tag(name="0.6.2", commit=Commit(sha="8482b0b3287b12db86eb0f70ab6cf2905db77c8a"))
# 0.6.2
# Tag(name="0.6.1", commit=Commit(sha="2c44f1cc00fa27772f6b5b71cc44bf706c167a17"))
# 0.6.1
# Tag(name="0.6.0", commit=Commit(sha="3fbc47d57bd25971260e3abb7ce276404b3f8bfb"))
# 0.6.0
# Tag(name="0.5.2", commit=Commit(sha="afd52a36b3f762d4e00c90a02601eb926f9c8b50"))
# 0.5.2
# Tag(name="0.5.1", commit=Commit(sha="1d192a32a4df533a8cd725ef25e420e6cc0456e0"))
# 0.5.1
# Tag(name="0.5.0", commit=Commit(sha="9162652dbeb44a686805c3463cc60eb4af9b9411"))
# 0.5.0

# %%
g = Github('tanjianjia@gmail.com', 'd8158219bffa0cd3371a9fb237289e30d6402de1', timeout=3000)


for 

repo = g.get_repo('apache/log4j')

for release in repo.get_tags():
    print(release)
# Out:
# Tag(name="v1.3alpha8", commit=Commit(sha="1201725868d7caa52dfa14e1d5630affbed39d9f"))
# Tag(name="v1.3alpha8-temp", commit=Commit(sha="bd04062f4ce92d108ae41fd41926de55a918372f"))
# Tag(name="v1_3alpha_6", commit=Commit(sha="fd3db80850343bd65e4296c6a85ba671d9860680"))
# Tag(name="v1_3alpha_1", commit=Commit(sha="3fc26dbfac760367db6368312c02bbbcbff3f8e9"))
# Tag(name="v1_2_17", commit=Commit(sha="de9f0ea504db9d1178db2cf45323d8e182a5df0a"))
# Tag(name="v1_2_17_rc3", commit=Commit(sha="e10785b7cd54b64cbc503540f8f6df8caa3c97bc"))
# Tag(name="v1_2_17_rc2", commit=Commit(sha="1b841d29f176ffdc0fa80df164afa123d559e2d6"))
# Tag(name="v1_2_17_rc1", commit=Commit(sha="1b1af8c7f932ea51a51a554489a4dbb9ee4e2ef5"))
# Tag(name="v1_2_17-rc1", commit=Commit(sha="e22d876235486703e3f9f6fa6f46f37138f5c71a"))
# Tag(name="v1_2_16", commit=Commit(sha="af948483a9659e049f536b0d359af48b1ec478b5"))
# Tag(name="v1_2_16_rc2", commit=Commit(sha="e01a290a07e761229a4e9d29e672cce3576b2b3f"))
# Tag(name="v1_2_16_rc1", commit=Commit(sha="13d9ae10bdc19f63b54faf536010970689dd2145"))
# Tag(name="v1_2_15", commit=Commit(sha="8014ad127c6ea4b4dcb23f06bad6dbbf7d092fe9"))
# Tag(name="v1_2_15_rc6", commit=Commit(sha="e025b747ec3b0acfb68ab2b4cbab5ca0a40a7696"))
# Tag(name="v1_2_15_rc5", commit=Commit(sha="ac1d06673e8a59eb671f9064d08640b9cd2972d5"))
# Tag(name="v1_2_15_rc4", commit=Commit(sha="c48c59874893aba3b933e858428a0f8cc846b5af"))
# Tag(name="v1_2_15_rc3", commit=Commit(sha="baa463abc7edf7a4a55758091b80979431967750"))
# Tag(name="v1_2_15_rc2", commit=Commit(sha="c9f856a4f7716e4aff094eb3ab5454a125509371"))
# Tag(name="v1_2_15_rc1", commit=Commit(sha="5915be9613679211c8e8b4abb0d8ca9535592e61"))
# Tag(name="v1_2_14", commit=Commit(sha="731e48fe29b36bfc6a126c3414d39a68f248a8ea"))
# Tag(name="v1_2_14_site_update", commit=Commit(sha="82bbddea4dfd776039a185c2255810e2ed61adfc"))
# Tag(name="v1_2_14_rc1", commit=Commit(sha="fdb5580354bc8545d12e9d929d4d45d05a630d7c"))
# Tag(name="v1_2_14_maven", commit=Commit(sha="ad84ff8d266b9e17ab54e4002f316737258bba22"))
# Tag(name="v1_2_13", commit=Commit(sha="2f10d668ef6f6ea725deaca8056e2ec1ec53f1d2"))
# Tag(name="v1_2_13_site_update", commit=Commit(sha="4ac01318e5c3d4b9a718a36f2305fe727933baf2"))
# Tag(name="v1_2_13_rc2", commit=Commit(sha="65878ea0cbd70338b6b210089a127b477e8d2724"))
# Tag(name="v1_2_13_rc1", commit=Commit(sha="f368391c2ee5455c8de8e6f1144fbf25b634f476"))
# Tag(name="v1_2_12", commit=Commit(sha="d4a62050f3d818b894168e6527c062326a7bb328"))
# Tag(name="v1_2_12_rc6", commit=Commit(sha="166f8d08ef1b4847268db1722f1d07edeb1ddde8"))
# Tag(name="v1_2_12_rc5", commit=Commit(sha="62016b216951bd5a90432a7ab8bd0cb4b67b38d1"))
# Tag(name="v1_2_12_rc4", commit=Commit(sha="3cf3009c2b1701b7c8e0c1ccbda1a2021cda8ded"))
# Tag(name="v1_2_12_rc3", commit=Commit(sha="c7e185e14e6cceea9248cded8f28c0410fee0985"))
# Tag(name="v1_2_12_rc2", commit=Commit(sha="ec55b446be952ef4a5d8a7a2682b790e6c604bf0"))
# Tag(name="v1_2_12_rc1", commit=Commit(sha="50de95aea222eb2068a7a04a9b3c3f1485b1f501"))
# Tag(name="v1_2_11", commit=Commit(sha="17490c317d8f2d8f99e4d8b49d517f2d949349ba"))
# Tag(name="v1_2_11rc3", commit=Commit(sha="08b2f40867d61c12337221cf73aaca1771531970"))
# Tag(name="v1_2_11_rc1", commit=Commit(sha="8e7604f7a6a722f222eec71b7fe9a7dbde46303e"))
# Tag(name="v1_2_10-recalled", commit=Commit(sha="d5aab726d1cf6bd113a7ddd708180918da29b5ef"))
# Tag(name="v1_2_9", commit=Commit(sha="744cea91b28ee6232eda1e8fb900cfe9169df703"))
# Tag(name="v1_2_7", commit=Commit(sha="6583ebca843d045cc88b6fbd7445426c78b2e8d4"))
# Tag(name="v1_2_6", commit=Commit(sha="c77c56c568a9b4072de3569c5ffb38c1afa6e941"))
# Tag(name="v1_2_4", commit=Commit(sha="3c29d38c95ee6166ec5e40ae33e9cffea2490581"))
# Tag(name="v1_2_3", commit=Commit(sha="3b9bf6d12198fbe0aba6e4bd751b85d1a5944860"))
# Tag(name="v1_2_2", commit=Commit(sha="5d9477505b7979478929c924328b9835c67495a9"))
# Tag(name="v1_2_1", commit=Commit(sha="bcb0db698886247cbf3fd4c7a10bff72e1d2215a"))
# Tag(name="v1_2final", commit=Commit(sha="f1be130772643baf9bd09713570afa2726db333e"))
# Tag(name="v_1_2beta3", commit=Commit(sha="cb675e3fe4b0e5d48da7777d688342e0a88bc4e6"))
# Tag(name="v1_2beta1", commit=Commit(sha="290a331a381070dcc07640e5b4e8dacc1f31d402"))
# Tag(name="v1_2_alpha7", commit=Commit(sha="60e494f51423189634e17274bb341a355fa0dee8"))
# Tag(name="v1_2_alpha0", commit=Commit(sha="c51d38ad85b5bc1ddfbb0dcba16a99e8242de9b7"))
# Tag(name="v_1_1_3", commit=Commit(sha="34f0a7524590b6e3afbbe26ff8f91a83b67a6a97"))
# Tag(name="v_1_1_2", commit=Commit(sha="f41873afdc46e06df6a3a1ee66dfb9e2657694ec"))
# Tag(name="v_1_1_1", commit=Commit(sha="fe662d204247e3bd9aacc2682d1db3cd74c92512"))
# Tag(name="v_1_1", commit=Commit(sha="950706ca18b5a8e6351caa29ec84d0c8b1544af7"))
# Tag(name="v_1_1b7", commit=Commit(sha="6e396cee3374b184b5cd8f806876673ef48f9efc"))
# Tag(name="v_1_1b6", commit=Commit(sha="c954838f5935130780ccf2fb178db8f5ae8404e3"))
# Tag(name="v_1_1b5", commit=Commit(sha="ee81d8c456e26edbcc1935306f4668c3092f2252"))
# Tag(name="v_1_1b3", commit=Commit(sha="3db4373ad5bf2f4bf212f581cabf0762bef44b32"))
# Tag(name="v_1_1b2", commit=Commit(sha="d921d578d8c84708ceedb099fba0e68c20dd85f9"))
# Tag(name="v_1_1_b1", commit=Commit(sha="8cba085d2614b7372266615199c56ba03da8b81b"))
# Tag(name="v_1_0_4", commit=Commit(sha="fca31abe1d8e75aa170a9e4a3bd2f0f5e3962c4f"))
# Tag(name="v_1_0_1", commit=Commit(sha="fa6a663c01c1c7c1585ad92045246e576a5eccda"))
# Tag(name="v_1_0", commit=Commit(sha="ae192513d4714e5dfbd514419b6bd1f6bbab2cae"))
# Tag(name="log4j-1.2.17", commit=Commit(sha="15477eef6d1a57ae7cfab8c64dbcb7a5e4469a6d"))
# Tag(name="log4j-1.2.17-rc1", commit=Commit(sha="3d739db1b5f274584c89b861ec38cd2dd59d5c64"))
# Tag(name="TAG_CHAINSAW2_MOVE", commit=Commit(sha="84939c1a093d2f35887d0a0236f3cf4d54c6b75c"))
# Tag(name="PREALPHA_1_3_AS_OF_2004_05_12", commit=Commit(sha="9df40aa32b015d33202863a439de32a875ebf572"))
# Tag(name="PRE_UGLI_MOVE", commit=Commit(sha="05749b0f14b5ddb42a5dde9488556f9119d5d22c"))
# Tag(name="PRE_CHAINSAW_MODEL_CONVERSION", commit=Commit(sha="1c364eb8ce55873aa58de373768ee09dd905ba0a"))
# Tag(name="LEVEL_REPLACES_PRIORITY", commit=Commit(sha="a3bbe94c4714988ba9ac7bbb8b69cd3a2760d047"))
# Tag(name="CORE_VERSION", commit=Commit(sha="61a6749932e85286950e033750ad7cce8c0bb105"))
# Tag(name="CHAINSAW_2_SANDBOX_MERGE", commit=Commit(sha="0e0d16540cc263a22fd137a6ea93e75ae5767a3b"))
# Tag(name="1.3alpha-7", commit=Commit(sha="7f24342fdbece1cf2cb2dea26c9e622930839a73"))
